# %% [markdown]
# # Version finale

# %%
# %matplotlib inline     
# ^Sans animations
# %matplotlib notebook 
# ^Avec animations
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
import math
import random
from random import uniform

# %% [markdown]
# ## I) Population (Catherine)##

# %% [markdown]
# Nous souhaitons obtenir l'évolution de la population jusqu'à une année "a" choisie sur chacun des continents.
#
# Celle-ci dépend de différents paramètres :
#
# **la population de départ**, dont les données ont été prises à l'année 2017 par l'ONU (on considère que l'année 2017 est l'année 0)
#
# **le taux d'accroissement**, dont les valeurs fixes viennent de l'INED
#
# **les imprévus** qui peuvent survenir, qui peuvent soit être positif, soit négatif

# %%
continents=["Europe", "Amérique du Nord","Asie", "Afrique", "Amérique du Sud", "Océanie"]

# %% [markdown]
# Nous avons décidé de se baser sur l'évolution exponentielle de la population, c'est l'évolution la plus réaliste.
#
# Elle suit la loi suivante :
#
# **N(t)=N0*exp(k*t)**
#
# N étant la population, N0 la population à la 1ère génération, k étant le taux d'accroissement, et t l'année.

# %% [markdown]
# Calcul du taux de croissance :
#
#
# ** k=(TN-TM)/POP **
#
# ** TN: taux de natalité **
#
# ** TM: taux de mortalité **
#
# ** POP: population à l'année considérée **

# %% [markdown]
# On souhaite avoir plusieurs situations. Il faut créer une fonction pour chaque continent, car la situation entre deux continents n'est pas forcément la même. Les notations sont cependant similaires pour chaque continent, n représentant le nombre de naissances, m le nombre de décès, probleme si un imprévu arrive, et s'il est positif ou fixe.

# %% [markdown]
# On veut obtenir **l'évolution de la population** à une année a choisie dans chaque continent.

# %%
pop={"Europe":[735394902,736315575,737021812,737561463,738015743,738442070,738849002,742074000],
     "Amérique du Nord":[344129116,347016566,349793414,352491844,355161292,357838035,360529323,361208000],
     "Asie":[4169860386,4215002029,4260153000,4305101589,4349560521,4393296013,4436224472,4504428000],
     "Afrique":[1044106862,1071200423,1099053331,1127576120,1156648751,1186178282,1216129814,1256268000], 
     "Amérique du Sud":[599822996,606877936,613873882,620799455,627640852,634386566,641029306,645593000],
     "Océanie":[36410779,37014521,37605013,38184665,38758785,39331130,39901355,40691000]}

u=uniform(-2.5,-2.3)
p=uniform(2.3,2.5)

def evolution_pop1(a,pop,n1,m1,probleme1,positif1,fixe1):
    """->dict[str:list[int]]"""
    
    popr={"Europe":[735394902,736315575,737021812,737561463,738015743,738442070,738849002,742074000]}
    
    for t in range(a):
        if popr["Europe"][t]!=0:
            def k1(n1,m1,positif1,fixe1):
                """-> float"""
            
                if positif1:
                    if fixe1:
                        k1=((n1-m1)/(popr["Europe"][t]))*p
                    else:
                        ch=uniform(2.3,2.5)
                        k1=((n1-m1)/(popr["Europe"][t]))*ch
                else:
                    if fixe1:
                        k1=((n1-m1)/(popr["Europe"][t]))*u
                    else:
                        ch=uniform(-2.5,-2.3)
                        k1=((n1-m1)/(popr["Europe"][t]))*ch
                return k1
    
            b=t+1
    
            if probleme1:
                popr["Europe"].append(round((pop["Europe"][7])*math.exp((k1(n1,m1,positif1,fixe1))*b)))
            else:
                popr["Europe"].append(round((pop["Europe"][7])*math.exp((k1(n1,m1,positif1,fixe1))*b)))
        else:
            popr["Europe"].append(0)
    return popr

# %%
def evolution_pop2(a,pop,n2,m2,probleme2,positif2,fixe2):
    """-> dict[str:list[int]]"""
    
    popr={"Amérique du Nord":[344129116,347016566,349793414,352491844,355161292,357838035,360529323,361208000]}
    
    for t in range(0,a):
        if popr["Amérique du Nord"][t]!=0:
            def k2(n2,m2,positif2,fixe2):
        
                if positif2:
                    if fixe2:
                        k2=((n2-m2)/(popr["Amérique du Nord"][t]))*p
                    else:
                        ch=uniform(2.3,2.5)
                        k2=((n2-m2)/(popr["Amérique du Nord"][t]))*ch
    
                else:
                    if fixe2:
                        k2=((n2-m2)/(popr["Amérique du Nord"][t]))*u
                    else:
                        ch=uniform(-2.5,-2.3)
                        k2=((n2-m2)/(popr["Amérique du Nord"][t]))*ch
                return k2
    
            b=t+1
        
            if probleme2:
                popr["Amérique du Nord"].append(round((pop["Amérique du Nord"][7])*math.exp((k2(n2,m2,positif2,fixe2))*b)))
            else: 
                popr["Amérique du Nord"].append(round((pop["Amérique du Nord"][7])*math.exp(0.0073*b)))
        else:
            popr["Amérique du Nord"].append(0)
    return popr

# %%
def evolution_pop3(a,pop,n3,m3,probleme3,positif3,fixe3):
    """-> dict[str:list[int]]"""
    
    popr={"Asie":[4169860386,4215002029,4260153000,4305101589,4349560521,4393296013,4436224472,4504428000]}
    
    for t in range(0,a):
        if popr["Asie"][t]!=0:
            def k3(n3,m3,positif3,fixe3):
        
                if positif3:
                    if fixe3:
                        k3=((n3-m3)/(popr["Asie"][t]))*p
                    else:
                        ch=uniform(2.3,2.5)
                        k3=((n3-m3)/(popr["Asie"][t]))*ch
    
                else:
                    if fixe3:
                        k3=((n3-m3)/(popr["Asie"][t]))*u
                    else:
                        ch=uniform(-2.5,-2.3)
                        k3=((n3-m3)/(popr["Asie"][t]))*ch
                return k3
    
            b=t+1
        
            if probleme3:
                popr["Asie"].append(round((pop["Asie"][7])*math.exp(k3(n3,m3,positif3,fixe3)*b)))
            else: 
                popr["Asie"].append(round((pop["Asie"][7])*math.exp(0.0085*b)))
        else:
            popr["Asie"].append(0)
    return popr

# %%
def evolution_pop4(a,pop,n4,m4,probleme4,positif4,fixe4):
    """-> dict[str:list[int]]"""
    
    popr={"Afrique":[1044106862,1071200423,1099053331,1127576120,1156648751,1186178282,1216129814,1256268000]}
    
    for t in range(0,a):
        if popr["Afrique"][t]!=0:
            def k4(n4,m4,positif4,fixe4):
        
                if positif4:
                    if fixe4:
                        k4=((n4-m4)/(popr["Afrique"][t]))*p
                    else:
                        ch=uniform(2.3,2.5)
                        k4=((n4-m4)/(popr["Afrique"][t]))*ch
    
                else:
                    if fixe4:
                        k4=((n4-m4)/(popr["Afrique"][t]))*u
                    else:
                        ch=uniform(-2.5,-2.3)
                        k4=((n4-m4)/(popr["Afrique"][t]))*ch
                return k4
        
            b=t+1
        
            if probleme4:
                popr["Afrique"].append(round((pop["Afrique"][7])*math.exp((k4(n4,m4,positif4,fixe4))*b)))
            else: 
                popr["Afrique"].append(round((pop["Afrique"][7])*math.exp(0.0245*b)))
        else:
            popr["Afrique"].append(0)
    return popr

# %%
def evolution_pop5(a,pop,n5,m5,probleme5,positif5,fixe5):
    """-> dict[str:list[int]]"""
    
    popr={"Amérique du Sud":[599822996,606877936,613873882,620799455,627640852,634386566,641029306,645593000]}
    
    for t in range(0,a):
        if popr["Amérique du Sud"][t]!=0:
            def k5(n5,m5,positif5,fixe5):
        
                if positif5:
                    if fixe5:
                        k5=((n5-m5)/(popr["Amérique du Sud"][t]))*p
                    else:
                        ch=uniform(2.3,2.5)
                        k5=((n5-m5)/(popr["Amérique du Sud"][t]))*ch
    
                else:
                    if fixe5:
                        k5=((n5-m5)/(popr["Amérique du Sud"][t]))*u
                    else:
                        ch=uniform(-2.5,-2.3)
                        k5=((n5-m5)/(popr["Amérique du Sud"][t]))*ch
                return k5
    
            b=t+1
        
            if probleme5:
                popr["Amérique du Sud"].append(round((pop["Amérique du Sud"][7])*math.exp((k5(n5,m5,positif5,fixe5))*b)))
            else: 
                popr["Amérique du Sud"].append(round((pop["Amérique du Sud"][7])*math.exp(0.0095*b)))
        else:
            popr["Amérique du Sud"].append(0)
    return popr

# %%
def evolution_pop6(a,pop,n6,m6,probleme6,positif6,fixe6):
    """-> dict[str:list[int]]"""
    
    popr={"Océanie":[36410779,37014521,37605013,38184665,38758785,39331130,39901355,40691000]}
    
    for t in range(0,a):
        if popr["Océanie"][t]!=0:
            def k6(n6,m6,positif6,fixe6):
        
                if positif6:
                    if fixe6:
                        k6=((n6-m6)/(popr["Océanie"][t]))*p
                    else:
                        ch=uniform(2,4)
                        k6=((n6-m6)/(popr["Océanie"][t]))*ch
    
                else:
                    if fixe6:
                        k6=((n6-m6)/(popr["Océanie"][t]))*u
                    else:
                        ch=uniform(-4,-2)
                        k6=((n6-m6)/(popr["Océanie"][t]))*ch
                return k6
    
            b=t+1
        
            if probleme6:
                popr["Océanie"].append(round((pop["Océanie"][7])*math.exp((k6(n6,m6,positif6,fixe6))*b)))
            else:
                popr["Océanie"].append(round((pop["Océanie"][7])*math.exp((k6(n6,m6,positif6,fixe6))*b)))
        else:
            popr["Océanie"].append(0)
    return popr

# %%
def evolution_pop(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,
                 n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6):
    
    """dict[str:list[int]]"""
    
    popr=dict()
    
    popr["Europe"]=evolution_pop1(a,pop,n1,m1,probleme1,positif1,fixe1)["Europe"]
    popr["Amérique du Nord"]=evolution_pop2(a,pop,n2,m2,probleme2,positif2,fixe2)["Amérique du Nord"]
    popr["Asie"]=evolution_pop3(a,pop,n3,m3,probleme3,positif3,fixe3)["Asie"]
    popr["Afrique"]=evolution_pop4(a,pop,n4,m4,probleme4,positif4,fixe4)["Afrique"]
    popr["Amérique du Sud"]=evolution_pop5(a,pop,n5,m5,probleme5,positif5,fixe5)["Amérique du Sud"]
    popr["Océanie"]=evolution_pop6(a,pop,n6,m6,probleme6,positif6,fixe6)["Océanie"]
    
    return popr

# %%
evolution_pop(5,pop,1235000,9845500,True,False,False,1536852,6548213,True,True,True,4561237,5462137,True,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,True,True,False)
# Out:
# {'Afrique': [1044106862,
#   1071200423,
#   1099053331,
#   1127576120,
#   1156648751,
#   1186178282,
#   1216129814,
#   1256268000,
#   1287426702,
#   1319358220,
#   1352081722,
#   1385616852,
#   1419983740],
#  'Amérique du Nord': [344129116,
#   347016566,
#   349793414,
#   352491844,
#   355161292,
#   357838035,
#   360529323,
#   361208000,
#   348320191,
#   336095363,
#   324479866,
#   313429515,
#   302910572],
#  'Amérique du Sud': [599822996,
#   606877936,
#   613873882,
#   620799455,
#   627640852,
#   634386566,
#   641029306,
#   645593000,
#   651755358,
#   657976538,
#   664257101,
#   670597613,
#   676998647],
#  'Asie': [4169860386,
#   4215002029,
#   4260153000,
#   4305101589,
#   4349560521,
#   4393296013,
#   4436224472,
#   4504428000,
#   4506698909,
#   4508922284,
#   4511099588,
#   4513232657,
#   4515323850],
#  'Europe': [735394902,
#   736315575,
#   737021812,
#   737561463,
#   738015743,
#   738442070,
#   738849002,
#   742074000,
#   762503438,
#   784439395,
#   808504751,
#   826559309,
#   849946625],
#  'Océanie': [36410779,
#   37014521,
#   37605013,
#   38184665,
#   38758785,
#   39331130,
#   39901355,
#   40691000,
#   32936883,
#   24529706,
#   19806314,
#   18590894,
#   13488229]}

# %%
evolution_pop2(10,pop,123000,984500,True,False,True)
# Out:
# {'Amérique du Nord': [344129116,
#   347016566,
#   349793414,
#   352491844,
#   355161292,
#   357838035,
#   360529323,
#   361208000,
#   363323707,
#   365416290,
#   367488094,
#   369540607,
#   371573995,
#   373587728,
#   375581637,
#   377649538,
#   379645944,
#   381630933]}

# %% [markdown]
# ### Graphique de la population mondiale

# %% [markdown]
# L1 : liste de la population en Europe
#
# L2 : liste de la population en Amérique du Nord
#
# L3 : liste de la population en Asie
#
# L4 : liste de la population en Afrique
#
# L5 : liste de la population en Amérique du Sud
#
# L6 : liste de la population en Océanie

# %% [markdown]
# A l'échelle mondiale, on regarde l'évolution de la population à l'année voulue.

# %%
def L7(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,
       fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6):
    """-> list[int]"""
    
    L7=list()
    
    L1=evolution_pop1(a,pop,n1,m1,probleme1,positif1,fixe1)["Europe"]
    L2=evolution_pop2(a,pop,n2,m2,probleme2,positif2,fixe2)["Amérique du Nord"]
    L3=evolution_pop3(a,pop,n3,m3,probleme3,positif3,fixe3)["Asie"]
    L4=evolution_pop4(a,pop,n4,m4,probleme4,positif4,fixe4)["Afrique"]
    L5=evolution_pop5(a,pop,n5,m5,probleme5,positif5,fixe5)["Amérique du Sud"]
    L6=evolution_pop6(a,pop,n6,m6,probleme6,positif6,fixe6)["Océanie"]
    
    for z in range(0,a):
        nb=L1[z]+L2[z]+L3[z]+L4[z]+L5[z]+L6[z]
        L7.append(nb)
    return L7

# %%
#L7(83,pop,933000,732000,False,False,False,169500,500000,False,False,True,420000,120000,True,False,False,1913502,13530,True,True,False,81530,19153,True,True,True,12032,81563,True,False,True)

# %%
L_annee=[i for i in range(2010,2100)]

# %%
def total(L7):
    """"""
    
    plt.figure()
    plt.plot(L_annee, L7)
    plt.legend(["Monde"])
    plt.xlabel("Année")
    plt.ylabel("Taille population")
    plt.show()
    return

# %%
L7=L7(90,pop,933000,732000,False,False,False,169500,500000,False,False,True,420000,120000,False,False,False,1913502,13530,False,True,False,81530,19153,False,True,True,12032,81563,False,False,True)
total(L7)

# %%
L7
# Out:
# [6929725041,
#  7013427050,
#  7097500452,
#  7181715136,
#  7265785944,
#  7349472096,
#  7432663272,
#  7550262000,
#  7628358622,
#  7707654547,
#  7788182719,
#  7869836724,
#  7952806379,
#  8037015532,
#  8122483050,
#  8209410258,
#  8297569892,
#  8387124604,
#  8478349386,
#  8570532848,
#  8664392205,
#  8759829684,
#  8856886645,
#  8955203069,
#  9055131879,
#  9156855917,
#  9259659248,
#  9364831000,
#  9471290352,
#  9579727220,
#  9689554764,
#  9801449539,
#  9916050010,
#  10031209486,
#  10148594210,
#  10268482907,
#  10390351402,
#  10514372012,
#  10639039642,
#  10767655493,
#  10898119099,
#  11030330160,
#  11164885397,
#  11300624854,
#  11440902427,
#  11581803214,
#  11726018694,
#  11872397136,
#  12021834756,
#  12173384560,
#  12328206206,
#  12486806150,
#  12646541881,
#  12809277978,
#  12975383963,
#  13143484620,
#  13315817730,
#  13490932503,
#  13670054693,
#  13849701883,
#  14035326373,
#  14224184675,
#  14416192364,
#  14610085769,
#  14808648812,
#  15011813684,
#  15217846827,
#  15427741547,
#  15642091877,
#  15860185369,
#  16083340983,
#  16309771075,
#  16540011100,
#  16776441486,
#  17015422296,
#  17261176694,
#  17508379581,
#  17764419445,
#  18021781999,
#  18286054334,
#  18556403574,
#  18829032876,
#  19108685838,
#  19396052689,
#  19686091328,
#  19983108123,
#  20284900070,
#  20592789774,
#  20907381191,
#  21230175222]

# %% [markdown]
# A l'échelle mondiale, on regarde cette fois-ci la population dans chaque continent. (c'est à dire que toutes les populations sont représentées sur un même graphique)

# %%
def list_pop(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,
       fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6):
    """->list[int]"""

    L1=evolution_pop1(a,pop,n1,m1,probleme1,positif1,fixe1)["Europe"]
    L2=evolution_pop2(a,pop,n2,m2,probleme2,positif2,fixe2)["Amérique du Nord"]
    L3=evolution_pop3(a,pop,n3,m3,probleme3,positif3,fixe3)["Asie"]
    L4=evolution_pop4(a,pop,n4,m4,probleme4,positif4,fixe4)["Afrique"]
    L5=evolution_pop5(a,pop,n5,m5,probleme5,positif5,fixe5)["Amérique du Sud"]
    L6=evolution_pop6(a,pop,n6,m6,probleme6,positif6,fixe6)["Océanie"]
    
    return L1,L2,L3,L4,L5,L6

# %%
list_pop(5,pop,933000,732000,False,False,False,169500,500000,False,False,True,420000,120000,True,False,False,1913502,13530,True,True,False,81530,19153,True,True,True,12032,81563,True,False,True)
# Out:
# ([735394902,
#   736315575,
#   737021812,
#   737561463,
#   738015743,
#   738442070,
#   738849002,
#   742074000,
#   741590450,
#   741125988,
#   740632166,
#   740107505,
#   739552189],
#  [344129116,
#   347016566,
#   349793414,
#   352491844,
#   355161292,
#   357838035,
#   360529323,
#   361208000,
#   363854466,
#   366520322,
#   369205710,
#   371910774,
#   374635656],
#  [4169860386,
#   4215002029,
#   4260153000,
#   4305101589,
#   4349560521,
#   4393296013,
#   4436224472,
#   4504428000,
#   4503634003,
#   4502878161,
#   4502177519,
#   4501522473,
#   4500617721],
#  [1044106862,
#   1071200423,
#   1099053331,
#   1127576120,
#   1156648751,
#   1186178282,
#   1216129814,
#   1256268000,
#   1261801260,
#   1267063166,
#   1272055918,
#   1277349148,
#   1281940464],
#  [599822996,
#   606877936,
#   613873882,
#   620799455,
#   627640852,
#   634386566,
#   641029306,
#   645593000,
#   645760521,
#   645924189,
#   646084183,
#   646240683,
#   646393874],
#  [36410779,
#   37014521,
#   37605013,
#   38184665,
#   38758785,
#   39331130,
#   39901355,
#   40691000,
#   40872681,
#   41049208,
#   41220982,
#   41388330,
#   41551447])

# %%
L_annee=[i for i in range(2010,2100)]

def plot_pop(L1,L2,L3,L4,L5,L6,pop):
    plt.figure()
    plt.plot(L_annee,L1)
    plt.plot(L_annee,L2)
    plt.plot(L_annee,L3)
    plt.plot(L_annee,L4)
    plt.plot(L_annee,L5)
    plt.plot(L_annee,L6)
    plt.legend([continent for continent in continents])
    plt.xlabel("Année")
    plt.ylabel("Taille population")
    plt.show()
    return

# %%
L1=evolution_pop1(82,pop,600000,30,False,False,True)["Europe"]
L2=evolution_pop2(82,pop,64652056,1269654,False,False,False)["Amérique du Nord"]
L3=evolution_pop3(82,pop,32458540,1941610,True,True,False)["Asie"]
L4=evolution_pop4(82,pop,12526560,325960,True,True,False)["Afrique"]
L5=evolution_pop5(82,pop,53103040,7801340,True,False,True)["Amérique du Sud"]
L6=evolution_pop6(82,pop,8001570,5815250,False,False,False)["Océanie"]

# %%
plot_pop(L1,L2,L3,L4,L5,L6,pop)

# %% [markdown]
# Même si nous voyons dans l'ensemble l'évolution de la population, les résultats sont trop imprécis pour en déduire quoique ce soit, du au fait que l'on prenne les résultats à l'échelle mondiale. Il faut donc visualiser la situation à l'échelle continentale.

# %% [markdown]
# ### Graphiques de la population sur chaque continent

# %%
def plot_pop1(L1,pop):
    plt.figure()
    plt.plot(L_annee,L1)
    plt.legend([continents[0]])
    plt.xlabel("Année")
    plt.ylabel("Taille population")
    plt.show()
    return

def plot_pop2(L2,pop):
    plt.figure()
    plt.plot(L_annee,L2, color="orange")
    plt.legend([continents[1]])
    plt.xlabel("Année")
    plt.ylabel("Taille population")
    plt.show()
    return

def plot_pop3(L3,pop):
    plt.figure()
    plt.plot(L_annee,L3, color="green")
    plt.legend([continents[2]])
    plt.xlabel("Année")
    plt.ylabel("Taille population")
    plt.show()
    return

def plot_pop4(L4,pop):
    plt.figure()
    plt.plot(L_annee,L4, color="red")
    plt.legend([continents[3]])
    plt.xlabel("Année")
    plt.ylabel("Taille population")
    plt.show()
    return

def plot_pop5(L5,pop):
    plt.figure()
    plt.plot(L_annee,L5, color="purple")
    plt.legend([continents[4]])
    plt.xlabel("Année")
    plt.ylabel("Taille population")
    plt.show()
    return

def plot_pop6(L6,pop):
    plt.figure()
    plt.plot(L_annee,L6, color="brown")
    plt.legend([continents[5]])
    plt.xlabel("Année")
    plt.ylabel("Taille population")
    plt.show()
    return

# %%
L1=evolution_pop1(82,pop,80,30,False,False,True)["Europe"]
L2=evolution_pop2(82,pop,64652056,1269654,False,False,False)["Amérique du Nord"]
L3=evolution_pop3(82,pop,32458540,1941610,True,True,False)["Asie"]
L4=evolution_pop4(82,pop,12526560,325960,True,True,False)["Afrique"]
L5=evolution_pop5(82,pop,10040,810,True,False,True)["Amérique du Sud"]
L6=evolution_pop6(82,pop,8001570,5815250,False,False,False)["Océanie"]

plot_pop1(L1,pop)
plot_pop2(L2,pop)
plot_pop3(L3,pop)
plot_pop4(L4,pop)
plot_pop5(L5,pop)
plot_pop6(L6,pop)

# %% [markdown]
# ## II) PIB (Cyrielle)##

# %% [markdown]
# # Modélisation du PIB #

# %% [markdown]
# ## Introduction ##

# %% [markdown]
# ### A) Formule ###

# %% [markdown]
# Le PIB s'exprime en dollars et se calcule de la façon suivante : PIB = CF + FBCF + VS + X - M
#
# Avec :
#
# - CF = consommation finale effective
#
# - FBCF = investissement (formation brute de capital fixe)
#
# - VS = variation des stocks
#
# - X = exportations
#
# - M = importations

# %% [markdown]
# ### B) Hypothèses ###

# %% [markdown]
# 1) On suppose que le cours du dollar ne change pas avec le temps. Il reste fixe à 1€ = 1,13$.
#
# 2) On suppose que le nombre d'entreprises est proportionnelle au nombre d'habitants.
#
# 3) On suppose que la variation des stocks est proportionnelle au nomnre d'entreprises.

# %% [markdown]
# ## I- PIB mondial (1ère approche : données France) ##

# %% [markdown]
# Le PIB mondial ne prend pas en compte les exportations et importations qui s'annulent.

# %% [markdown]
# ### 1) Calcul de CF ###

# %% [markdown]
# On définit la consommation finale par : dépense moyenne annuelle * nb de personnes
#
# La dépense moyenne annuelle change selon le type de foyer (d'après l'Insee avec les valeurs françaises):
#
# 1 personne : 16 641€ soit 18 785$
#
# 2 personnes : 18 000€ soit 20 319$
#
# 3 personnes : 23 016€ soit 25 981$
#
# 4 personnes : 30 684€ soit 34 637$
#
# 5 personnes : 32 653€ soit 36 860$
#
# Nous avons la proportions de chaque foyer en France :
#
# 1 personne : 35%
#
# 2 personnes : 33%
#
# 3 personnes : 14%
#
# 4 personnes : 12%
#
# 5 personnes : 6%
#
# Nous calculons la proportion de personnes vivant dans un foyer de 1, 2, 3, 4 ou 5 personnes. Pour cela nous calculons grâce aux proportions ci-dessus, le nombre de personnes totales d'une population.
#
# 35 + 33 * 2 + 14 * 3 + 12 * 4 + 6 * 5 = 221
#
# Ainsi, nous ressortons les proportions de personnes vivant dans chaque type de foyer :
#
# 1 personne : 35 / 221 * 100 = 16%
#
# 2 personnes : 33 2 / 221 * 100 = 30%
#
# 3 personnes : 14 3 / 221 * 100 = 19%
#
# 4 personnes : 12 4 / 221 * 100 = 22%
#
# 5 personnes : 5 6 / 221 * 100 = 13%

# %%
pe={1:0.16, 2:0.30, 3:0.19, 4:0.22, 5:0.13} #proportion de personnes vivants dans un certain foyer
d={1:18785, 2:20319, 3:25981, 4:34637, 5:36860} #dépenses du foyer

# %%
def CF(popf, pe, d):
    """int*dict[int:float]*dict[int:int]->float"""
    D=dict()
    for i in pe:
        D[i]=popf*pe[i]
    DR=dict()
    for j in D:
        DR[j]=D[j]*d[j]/j
    s=0
    for k in DR:
        s=DR[k]+s
    return s

# %%
CF(7550262000, pe, d)
# Out:
# 79748195241450.0

# %% [markdown]
# ### 2) Calcul du FBCF ###

# %% [markdown]
# Le FBCF se calcule par la somme des achats et travaux immobiliers des particuliers et les investissements des entreprises et institutions publiques.
#
# En 2017, il y a, d'après l'Insee, 515 900 000 000€ investissements des institutions et entreprises françaises. Soit 582 476 895 000$.
#
# En 2017, il y a, 4 751 553 entreprises et institutions françaises. Il y a également 67 120 000 habitants en France.
#
# Nous pouvons donc dire qu'approximativement 1 entreprise investit 582 476 895 000 / 4 751 553$ par an.
#
# Une entreprise investit donc 122 587$ par an.
#
# Pour déterminer le nombre d'entreprises on fait un produit en croix : 4 751 553 * pop / 67 120 000.

# %%
 fbcf={1:953, 2:2106, 3:738, 4:2378, 5:1589} #dépenses des particuliers

# %%
def FBCF(popf, fbcf, pe):
    """int*dict[int:int]*dict[int:float]->float"""
    D=dict()
    for i in pe:
        D[i]=popf*pe[i]
    DR=dict()
    for j in D:
        DR[j]=D[j]*fbcf[j]/j
    s=round(4751553*popf*122587/67120000)
    for k in DR:
        s=s+DR[k]
    return s

# %%
FBCF(7550262000, fbcf, pe)
# Out:
# 70711162371036.0

# %% [markdown]
# ### 3) Calcul de VS ###

# %% [markdown]
# La variation des stocks se calcule grâce aux stocksde début d'année moins les tsocks de fin d'années.
#
# En 2017, en France, d'après l'Insee, il y a 21 000 000 000€ de variation de stocks, soit 23 698 017 000$.
#
# Il y a 4 751 553 entreprises et institutions en France en 2017.
#
# On calcule donc la variation de stocks pour une entreprise : 23 698 017 000 / 4 751 553$.
#
# Une entreprise a donc une variation de stock d'environ 4 987$.

# %%
def VS(popf):
    """int->number"""
    e=round(4751553*popf/67120000) #nombre d'entreprises
    return e*4987

# %%
VS(7550262000)
# Out:
# 2665538872916

# %% [markdown]
# ### Calcul du PIB mondial ###

# %%
def PIB(popf, pe, d, fbcf):
    """int*dict[int:float]*dict[int:int]*dict[int*int]->float"""
    cfu=CF(popf, pe, d)
    fbcfu=FBCF(popf, fbcf, pe)
    vsu=VS(popf)
    return cfu+fbcfu+vsu

# %%
PIB(7550262000, pe, d, fbcf)
# Out:
# 153124896485402.0

# %% [markdown]
# La première approximation est éloignée de la réalité puisque le PIB de 2017 mondial était de 79 865 000 000 000$.

# %% [markdown]
# ## II- PIB mondial (2ème approche : données par continents)

# %% [markdown]
# ### 1) Calcul de CF

# %% [markdown]
# On estime grâce aux valeurs de la banque mondiale les données ci-dessous (il s'agit de prendre en compte la plus grande région du continent pour être le plus précis possible) :
#
# Les dépenses de consommations finales par habitant de chaque continents en 2016-2017 sont :
#
# - Afrique : Afrique du Nord (189 268 020 hab) et Moyen-Orient (415 385 000 hab) + Afrique Subsaharienne (1 022 664 451 hab) = 3 416.37 (CF par hab en AN et MO) + 1 028 (CF par hab en AS) = ((nb hab AN + MO) * 3 416.37 + nb hab AS * 1 028)/(nb hab tot) = 1 915$
#
# - Asie : Asie de l'Est et Pacifique (1 624 853 705 hab) + Asie du Sud (1 870 460 803 hab) + Russie (142 300 000 hab) = 4 637.10 (CF par hab en AS et P) + 1 059.60 (CF par hab en AS) + 5 874 (CF par hab en R) = ((nb hab AS + P) * 4 637.10 + nb hab AS * 1 029.60 + nb hab R * 5 874)/(nb hab tot) = 2 831$
#
# - Amérique du Nord : Amérique du Nord (donnée déjà calculée) = 35 639$
#
# - Amérique du Sud : Amérique latine et Caraïbes (donnée déjà calculée) = 5 668$
#
# - Europe : Europe centrale (200 000 000 hab) et Pays Baltes (6 826 000 hab) + Union Européenne (512 000 000 hab) = 8 902.27 (CF par hab en EC et PB) + 20 314.23 (CF par hab en UE) = ((nb hab EC + PB) * 8 902.27 + nb hab UE * 20 314.23)/(nb hab tot) = 17 031$
#
# - Océanie : Australie (24 641 661 hab) + Nouvelle Zélande (4 604 871 hab) = 31 410.64 (CF par hab en A) + 22 434.13 (CF par hab en NZ) = (nb hab A * 31 410.64 + nb hab NZ * 22 434.13)/(nb hab tot) = 29 997$

# %%
cfc={"Afrique":1915, "Asie":2831, "Amérique du Nord":35639, "Amérique du Sud":5668, "Europe":17031, "Océanie":29997}
continents=["Europe", "Amérique du Nord","Asie", "Afrique", "Amérique du Sud", "Océanie"]
pop2017={"Europe":742074000,"Amérique du Nord":361208000,"Asie":4504428000,"Afrique":1256268000, 
            "Amérique du Sud":645593000,"Océanie":40691000}

# %%
def cf_continents(cfc, continents, pop2017):
    """dict[str:int]*list[str]*dict[str:int]->int"""
    s=0
    for i in continents:
        s=s+cfc[i]*pop2017[i]
    return s

# %%
cf_continents(cfc, continents, pop2017)
# Out:
# 45548972145000

# %% [markdown]
# ### 2) Calcul du FBCF

# %% [markdown]
# On décide pour la deuxième partie de ne pas séparer les consommation des particuliers et celles des entreprises.
#
# On estime grâce aux valeurs de la banque mondiale les données ci-dessous pour le FBCF par habitant. Nous prenons le même nombre d'habitants pour chaque région que pour le CF.
#
# Afrique : Afrique du Nord et Moyen-Orient + Afrique Subsaharienne = (957 612 910 000 (FBCF de la région AN + MO) + 361 913 030 000 (FBCF de la région AS))/(nb hab AN + MO + AS) = 811$
#
# Asie : Asie de l'Est et Pacifique + Asie du Sud + Russie = (8 167 609 820 000 (FBCF de la régio AE + P) + 1 049 269 340 000 (FBCF de la région AS) + 390 369 330 000 (FBCF de la région R))/(nb hab AE + P + AS + R) = 2 641$
#
# Amérique du Nord : Amérique du Nord (361 208 000 hab) = 3 788 598 830 000 (FBCF de la région AN)/(nb hab AN) = 10 489$
#
# Amérique du Sud : Amérique latine et Caraïbes (647 565 335) = 1 131 073 580 000 (FBCF de la région AL +C)/(nb hab AL + C) = 1747$
#
# Europe : Europe centrale et Pays Baltes + Union Européenne = (360 640 590 000 (FBCF de la région EC + PB) + 3 943 976 300 000 (FBCF de la région UE)/(nb hab EC + PB + UE) = 5 988$
#
# Océanie : Australie + Nouvelle-Zélande = (333 107 700 000 (FBCF de la région A) + 41 880 470 000 (FBCF de la région NZ)/(nb hab A + NZ) = 12 822$

# %%
fbcfc={"Afrique":811, "Asie":2641, "Amérique du Nord":10489, "Amérique du Sud":1747, "Europe":5988, "Océanie":12822}

# %%
def fbcf_continents(fbcfc, continents, pop2017):
    """dict[str:int]*list[str]*dict[str:int]->int"""
    s=0
    for i in continents :
        s=s+fbcfc[i]*pop2017[i]
    return s

# %%
fbcf_continents(fbcfc, continents, pop2017)
# Out:
# 22796868493000

# %% [markdown]
# ### 3) Calcul de VS

# %% [markdown]
# On estime les données de variation de stocks par continent et par habitant en fonction des données par pays données par la banque mondiale :
#
# Afrique : Nous prenons 35 pays : (Somme des VS des 35 pays)/(nb hab des 35 pays) = 25 882 545 790/815 970 010 = 32$
#
# Asie : Nous prenons 31 pays : (Somme des VS des 31 pays)/(nb hab des 31 pays) = 224 074 187 950/4 092 924 088 = 55$
#
# Amérique du Nord : Nous prenons 3 pays : (Somme des VS des 3 pays)/(nb hab des 3 pays) = 55 557 762 400/493 322 910 = 113$
#
# Amérique du Sud : Nous prenons 15 pays : (Somme des VS des 15 pays)/(nb hab des 15 pays) = 28 727 147 680/418 773 224 = 69$
#
# Europe : Nous prenons 38 pays : (Somme des VS des 38 pays)/(nb hab des 38 pays) = 63 185 345 240/595 237 863 = 106$
#
# Océanie : Nous prenons 3 pays : (Somme des VS des 3 pays)/(nb hab des 3 pays) = 2 866 156 836/29 267 823 = 98$

# %%
vsc={"Afrique":32, "Asie":55, "Amérique du Nord":113, "Amérique du Sud":69, "Europe":106, "Océanie":98}

# %%
def vs_continents(vsc, continents, pop2017):
    """dict[str:int]*list[str]*dict[str:int]->int"""
    s=0
    for i in continents:
        s=s+vsc[i]*pop2017[i]
    return s

# %%
vs_continents(vsc, continents, pop2017)
# Out:
# 455954099000

# %% [markdown]
# ### Calcul du PIB

# %%
def PIB_continents(cfc, fbcfc, vsc, continents, pop2017):
    """dict[str:int]*dict[str:int]*dict[str:int]*list[str]*dict[str:int]->int"""
    cfcu=cf_continents(cfc, continents, pop2017)
    fbcfcu=fbcf_continents(fbcfc, continents, pop2017)
    vscu=vs_continents(vsc, continents, pop2017)
    return cfcu+fbcfcu+vscu

# %%
PIB_continents(cfc, fbcfc, vsc, continents, pop2017)
# Out:
# 68801794737000

# %% [markdown]
# Le PIB mondial de 2017 était de 79 865 000 000 000$.
#
# Il reste encore environ 10 000 000 000 000$ de différence entre la modélisation et la valeur réelle.

# %% [markdown]
# ## III- PIB mondial (3ème approche : Régression linéaire)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

pib_data = pd.read_csv("./pib.csv")

# %%
annee = pib_data.iloc[0:len(pib_data),0]
PIB = pib_data.iloc[0:len(pib_data),1] 
X=[i for i in annee]
Y=[i for i in PIB]

# %%
axes = plt.axes()
axes.grid()
plt.plot(X, Y)
plt.xlabel('Année')
plt.ylabel('PIB en $')
plt.show()

# %%
def predict(slope, intercept, x):
    
    return slope*np.asarray(x) + intercept

# %%
def graph():
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du paramètre PIB')
    plt.xlabel('Année')
    plt.ylabel('PIB en $')
    plt.plot(X , Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()
    
def PIB(year):
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    return slope*year + intercept

# %%
graph()

# %%
def futur_mondial(year):
    """int->list[float]"""
    L=[]
    for i in range(2010,year):
        L.append(PIB(i))
    return L

# %%
L=futur_mondial(2101)
annee_futur=[i for i in range(2010,2101)]
def graph_monde():
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du paramètre PIB')
    plt.xlabel('Année')
    plt.ylabel('PIB en $')
    plt.plot(annee_futur, L)
    plt.show()

# %%
graph_monde()

# %%
PIB(2017)
# Out:
# 67872053087868.5

# %% [markdown]
# Le PIB mondial de 2017 était de 79 865 000 000 000$.
#
# Notre deuxième approche (PIB par continents) était plus proche de la réalité que celle-ci. Ainsi, nous prendrons la deuxième approche pour modéliser le futur.
# De plus l'approche par population parait plus réaliste. Si la population diminue, le PIB doit également diminuer.

# %% [markdown]
# ## IV- PIB continental

# %% [markdown]
# On utilise les même données que dans le PIB mondial par continent.

# %% [markdown]
# ### 1) Calcul de CF

# %%
cfc={"Afrique":1915, "Asie":2831, "Amérique du Nord":35639, "Amérique du Sud":5668, "Europe":17031, "Océanie":29997}
continents=["Europe", "Amérique du Nord","Asie", "Afrique", "Amérique du Sud", "Océanie"]
pop2017={"Europe":742074000,"Amérique du Nord":361208000,"Asie":4504428000,"Afrique":1256268000, 
            "Amérique du Sud":645593000,"Océanie":40691000}

# %%
def cf_continental(cfc, continents, pop2017, continent):
    """dict[str:int]*list[str]*dict[str:int]*str->int"""
    s=0
    for i in continents:
        if i==continent:
            s=s+cfc[i]*pop2017[i]
    return s

# %%
cf_continental(cfc, continents, pop2017, "Europe")
# Out:
# 12638262294000

# %% [markdown]
# ### 2) Calcul du FBCF

# %%
fbcfc={"Afrique":811, "Asie":2641, "Amérique du Nord":10489, "Amérique du Sud":1747, "Europe":5988, "Océanie":12822}

# %%
def fbcf_continental(fbcfc, continents, pop2017, continent):
    """dict[str:int]*list[str]*dict[str:int]*str->int"""
    s=0
    for i in continents :
        if i==continent:
            s=s+fbcfc[i]*pop2017[i]
    return s

# %%
fbcf_continental(fbcfc, continents, pop2017, "Europe")
# Out:
# 4443539112000

# %% [markdown]
# ### 3) Calcul de VS

# %%
vsc={"Afrique":32, "Asie":55, "Amérique du Nord":113, "Amérique du Sud":69, "Europe":106, "Océanie":98}

# %%
def vs_continental(vsc, continents, pop2017, continent):
    """dict[str:int]*list[str]*dict[str:int]*str->int"""
    s=0
    for i in continents:
        if i==continent:
            s=s+vsc[i]*pop2017[i]
    return s

# %%
vs_continental(vsc, continents, pop2017, "Europe")
# Out:
# 78659844000

# %% [markdown]
# ### 4) Calcul de X

# %% [markdown]
# D'après le site Perspective les exportations par continent en 2016/2017 sont :
#
# Afrique : 450 141 000 000$
#
# Asie : 6 622 214 000 000$
#
# Amérique du Nord : 3 089 941 000 000$
#
# Amérique du Sud : 603 638 000 000$
#
# Europe : 8 560 857 000 000$
#
# Océanie : 281 453 000 000$

# %%
xc={"Afrique":450141000000, "Asie":6622214000000, "Amérique du Nord":3089941000000, "Amérique du Sud":603638000000, "Europe":8560857000000, "Océanie":281453000000}

# %%
def x_continental(xc, continent):
    """dict[str:int]*str->int"""
    return xc[continent]

# %%
x_continental(xc,"Europe")
# Out:
# 8560857000000

# %% [markdown]
# ### 5) Calcul de M

# %% [markdown]
# D'après le site de Perspective les importations par continents en 2016/2017 sont :
#
# Afrique : 590 331 000 000$
#
# Asie : 6 084 681 000 000$
#
# Amérique du Nord : 3 669 595 000 000$
#
# Amérique du Sud : 644 905 000 000$
#
# Europe : 7 870 121 000 000$
#
# Océanie : 308 229 000 000$

# %%
mc={"Afrique":590331000000, "Asie":6084681000000, "Amérique du Nord":3669595000000, "Amérique du Sud":644905000000, "Europe":7870121000000, "Océanie":308229000000}

# %%
def m_continental(mc, continent):
    """dict[str:int]*str"""
    return mc[continent]

# %%
m_continental(mc, "Europe")
# Out:
# 7870121000000

# %% [markdown]
# ### Calcul du PIB

# %%
def PIB_continental(cfc, fbcfc, vsc, continents, xc, mc, pop2017, continent):
    """dict[str:int]*dict[str:int]*dict[str:int]*list[str]*dict[str:int]*dict[str:int]*dict[str:int]*str->int"""
    cfcu=cf_continental(cfc, continents, pop2017, continent)
    fbcfcu=fbcf_continental(fbcfc, continents, pop2017, continent)
    vscu=vs_continental(vsc, continents, pop2017, continent)
    xu=x_continental(xc, continent)
    mu=m_continental(mc, continent)
    return cfcu+fbcfcu+vscu+xu-mu

# %%
PIB_continental(cfc, fbcfc, vsc, continents, xc, mc, pop2017, "Europe")
# Out:
# 17851197250000

# %%
def PIB_6continents(cfc, fbcfc, vsc, continents, xc, mc, pop):
    """dict[str:int]*dict[str:int]*dict[str:int]*list[str]*dict[str:int]*dict[str:int]*dict[str:int]->dict[str:int]"""
    D=dict()
    for i in continents:
        D[i]=PIB_continental(cfc, fbcfc, vsc, continents, xc, mc, pop, i)
    return D

# %%
PIB_6continents(cfc, fbcfc, vsc, continents, xc, mc, pop2017)
# Out:
# {'Afrique': 3324597144000,
#  'Amérique du Nord': 16122965128000,
#  'Amérique du Sud': 4790351012000,
#  'Asie': 25433506556000,
#  'Europe': 17851197250000,
#  'Océanie': 1719559647000}

# %% [markdown]
# ### Evolution PIB

# %%
def evolution_PIB(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6,cfc,fbcfc,vsc,continents,xc,mc):
    D={"Europe":[],"Amérique du Nord":[],"Asie":[],"Afrique":[],"Amérique du Sud":[],"Océanie":[]}
    popu=evolution_pop(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6)
    
    for i in range(0,a+1):
        popx=dict()
        for k in continents:
            popx[k]=popu[k][i]
        for j in continents:
            D[j].append(PIB_continental(cfc, fbcfc, vsc, continents, xc, mc, popx, j))
    return D

# %%
evolution_PIB(5,pop,1235000,9845500,True,False,False,1536852,6548213,True,True,True,4561237,5462137,True,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,True,True,False,cfc,fbcfc,vsc,continents,xc,mc)
# Out:
# {'Afrique': [2739456725396,
#   2814180766634,
#   2890999086898,
#   2969664938960,
#   3049847255258,
#   3131289701756],
#  'Amérique du Nord': [15333220452956,
#   15466739028406,
#   15595143256774,
#   15719921358404,
#   15843359303372,
#   15967134576435],
#  'Amérique du Sud': [4447808302064,
#   4500607473024,
#   4552965132888,
#   4604796121220,
#   4655997136368,
#   4706482059944],
#  'Asie': [23584351353422,
#   23833849214283,
#   24083398631000,
#   24331829482403,
#   24577553999567,
#   24819280063851],
#  'Europe': [17696743108750,
#   17718033671875,
#   17734365402500,
#   17746844831875,
#   17757350056875,
#   17767208868750],
#  'Océanie': [1535865402343,
#   1561776197757,
#   1587118342921,
#   1611995267805,
#   1636634775845,
#   1661198106210]}

# %%
L_annee=[i for i in range(2010,2100)]

def plot_PIB_continental(L1,L2,L3,L4,L5,L6):
    plt.figure()
    plt.plot(L_annee,L1)
    plt.plot(L_annee,L2)
    plt.plot(L_annee,L3)
    plt.plot(L_annee,L4)
    plt.plot(L_annee,L5)
    plt.plot(L_annee,L6)
    plt.legend([continent for continent in continents])
    plt.xlabel("Année")
    plt.ylabel("PIB")
    plt.show()
    return

# %%
PIB1=evolution_PIB(89,pop,1235000,9845500,True,False,False,1536852,6548213,True,True,True,4561237,5462137,True,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,True,True,False,cfc,fbcfc,vsc,continents,xc,mc)
L1=PIB1["Europe"]
L2=PIB1["Amérique du Nord"]
L3=PIB1["Asie"]
L4=PIB1["Afrique"]
L5=PIB1["Amérique du Sud"]
L6=PIB1["Océanie"]

# %%
plot_PIB_continental(L1,L2,L3,L4,L5,L6)

# %%
def evolution_PIB_mondial(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6,cfc,fbcfc,vsc,continents,xc,mc):
    L=[]
    for i in range(0,a+1):
        s=0
        for j in continents:
            s=s+evolution_PIB(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6,cfc,fbcfc,vsc,continents,xc,mc)[j][i]
        L.append(s)
    return L

# %%
evolution_PIB_mondial(5,pop,1235000,9845500,True,False,False,1536852,6548213,True,True,True,4561237,5462137,True,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,True,True,False,cfc,fbcfc,vsc,continents,xc,mc)
# Out:
# [65337445344931,
#  65895186351979,
#  66443989852981,
#  66985052000667,
#  67520742527285,
#  68052593376946]

# %%
def plot_PIB_mondial(L):
    plt.figure()
    plt.plot(L_annee,L)
    plt.xlabel("Année")
    plt.ylabel("PIB")
    plt.show()
    return

# %%
L=evolution_PIB_mondial(89,pop,1235000,9845500,True,False,False,1536852,6548213,True,True,True,4561237,5462137,True,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,True,True,False,cfc,fbcfc,vsc,continents,xc,mc)

# %%
plot_PIB_mondial(L)

# %%
evolution_PIB_mondial(99,pop,1235000,9845500,True,False,False,1536852,6548213,True,True,True,4561237,5462137,True,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,True,True,False,cfc,fbcfc,vsc,continents,xc,mc)[49]
# Out:
# 76572766160875

# %%
evolution_PIB_mondial(99,pop,1235000,9845500,True,False,False,1536852,6548213,True,True,True,4561237,5462137,True,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,True,True,False,cfc,fbcfc,vsc,continents,xc,mc)[99]
# Out:
# 121500094655096

# %%
Lvrai=evolution_PIB_mondial(89,pop,1235000,9845500,False,False,False,1536852,6548213,False,True,True,4561237,5462137,False,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,False,True,False,cfc,fbcfc,vsc,continents,xc,mc)
Lvrai[33]
# Out:
# 92785032440423

# %%
plot_PIB_mondial(Lvrai)

# %%
Lvrai[33]-L[0] #2050-2017
# Out:
# 27447587095492

# %% [markdown]
# ## III) TEP (Thanh)

# %% [markdown]
# # Introduction

# %% [markdown]
# ## Hypothèse and bases de données

# %% [markdown]
# Nous allons prendre en compte tout l'énergie consommée sans faire distinction entre les
# différentes énergies existantes.
#
# Nos données de l'énergie sont exprimées en millions de tonnes équivalent pétrole (Mtep)
# soit 1,163e+13 Wh .

# %% [markdown]
# ## 1) Régression linéaire de données existantes

# %% [markdown]
# Nous allons se baser sur les données que nous offre le site Enerdata afin de crée notre
# régression linéaire de l'énergie consommée.
#
# Nous avons récupéré les données de l'énergie consomée de nombreux pays, groupe de pays ou région du monde sous une forme excel. Nous l'avons modifié afin de le transformer en csv nous utiliserons pandas afin de traiter ces données sous forme de tableau, nous manipulons alors les dataframes de python.
#
# Ces données sont datées de 1990 jusqu'à 2017, nous avons donc un certaines précisions dû au nombre de données

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pylab
from scipy import stats

# %% [markdown]
# On récupère une grande liste de pays, groupe de pays et continent mais nous allons nous contenter d'utiliser les mêmes pays que mes autres collègues pour nos fonctions.

# %%
energy_consumption = pd.read_csv("./Enerdata_Energy_Statistical_Yearbook2_20183.csv", index_col=0)
print(energy_consumption.index)
# Out:
# Index(['Monde', 'OECD', 'G7', 'BRICS', 'Europe', 'European Union', 'Belgium',
#        'Czech Rep.', 'France', 'Germany', 'Italy', 'Netherlands', 'Poland',
#        'Portugal', 'Romania', 'Spain', 'Sweden', 'United Kingdom', 'Norway',
#        'Turkey', 'CIS', 'Kazakhstan', 'Russia', 'Ukraine', 'Uzbekistan',
#        'America', 'Amerique du Nord', 'Canada', 'United States',
#        'Latin America', 'Argentina', 'Brazil', 'Chile', 'Colombia', 'Mexico',
#        'Venezuela', 'Asie', 'China', 'India', 'Indonesia', 'Japan', 'Malaysia',
#        'South Korea', 'Taiwan', 'Thailand', 'Pacific', 'Australia',
#        'New Zealand', 'Afrique', 'Algeria', 'Egypt', 'Nigeria', 'South Africa',
#        'Middle-East', 'Iran', 'Kuwait', 'Saudi Arabia',
#        'United Arab Emirates'],
#       dtype='object', name='Year')

# %% [markdown]
# On récupère les données du pays voulu grâce à la fonction "region" puis grâce à la fonction "graph" nous faisons la régression linéaire des données et nous l'affichons dans un tableau
# J'ai choisi de laisser les données sur le graphique afin qu'on puisse aperçevoir notre régression linéaire et nous estimions à l'oeil s'il parait réaliste ou non.

# %%
Annee = [int(i) for i in energy_consumption.columns]

def region(P):
    'Sélectionne les données du pays P'
    
    return energy_consumption.loc[P]

def predict(slope, intercept, x):
    'Fonction après la régression linéaire'
    
    return slope*np.asarray(x) + intercept

def graph(P):
    """ P est le pays ou une région du monde"""
    
    X = [int(i) for i in energy_consumption.columns]
    Y = list(region(P))
    
    axes = plt.axes()
    axes.grid()
    plt.title(P)
    plt.xlabel('Année')
    plt.ylabel('Consommation en MTEP')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()

# %%
graph('Monde')

# %% [markdown]
# Nous pouvons alors récupérer une donnée après la regression linéaire de nimporte quel pays, groupe de pays ou région du monde à nimporte quel année voulu grâce à la fonction "energy".

# %%
def energy(P, year):
    """ P est un pays ou une région du monde"""
    
    X = Annee
    Y = list(region(P))
        
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    return slope*year + intercept

# %%
energy('Monde', 2069)
# Out:
# 25635.975369458203

# %% [markdown]
# On peut rajouter un paramètre suplémentaire à mes fonctions précédente : un taux de chute (%) où notre croissance d'énergie consommée diminurait au fil des années à partir d'une année voulu (annee_chute).

# %%
Annee = [int(i) for i in energy_consumption.columns]

def predict_bis_chute(slope, intercept, annee_chute,pourcentage, X):
    
    slope_pre = slope
    valeur = []
    valeur_pre = (slope*annee_chute + intercept)
    e = 0
    
    if pourcentage == 0:
        return slope*np.asarray(X) + intercept
    
    for i in range(0, len(X)):
        if slope_pre > 1 and e == 0 :      
            valeur.append(valeur_pre+slope_pre) 
            valeur_pre = valeur_pre+slope_pre
            slope_pre = slope_pre*(1-pourcentage/100)

        else:        
            e = 1
            valeur.append(valeur_pre+slope_pre) 
            valeur_pre = valeur_pre-slope_pre
            slope_pre = slope_pre*(1+pourcentage/100)
     
    return valeur

def graph_bis(P, annee_final, annee_chute, pourcentage):
    """ P est le pays ou une région du monde en str"""
    
    X = [int(i) for i in energy_consumption.columns]
    Y = list(region(P))
    X_bis = [ i for i in range(1990, annee_chute)]
    X_bis2 = [ i for i in range(annee_chute, annee_final)]
    
    axes = plt.axes()
    axes.grid()
    plt.title(P)
    plt.xlabel('Année')
    plt.ylabel('Consommation en MTEP')
    plt.scatter(X,Y)
    
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X_bis, predict(slope, intercept, X_bis), c='r') 
    
    plt.plot(X_bis2, predict_bis_chute(slope, intercept, annee_chute,pourcentage, X_bis2), c='g')
    plt.ylim(0,) 
    plt.show()

# %% [markdown]
# On peut donc maintenant avoir un graphique qui s'arrêtera à une année final voulu et une variation de notre courbe d'évolution à partir d'une année voulu.
# Les points bleus représentent les données, la courbe rouge représente la regression linéaire et la courbe verte représente l'évolution de l'énergie consommé après qu'un certain taux diminue chaque année.

# %%
graph_bis("Monde", 2350, 2050, 4)

# %% [markdown]
# On peut ainsi récupéré nos valeurs avec un choix d'intervalle d'année avec la fonction suivante:

# %%
def energie_avec_chute(P,annee_debut, annee_final, annee_chute,pourcentage):
    
    X_regre = [int(i) for i in energy_consumption.columns]
    Y = list(region(P))
    X_bis2 = [ i for i in range(annee_chute, annee_final)]
    X = [i for i in range(annee_debut, annee_final)]
    
    slope, intercept, r_value, p_value, std_err = stats.linregress(X_regre, Y)
    
    slope_pre = slope
    list_valeur = []
    valeur_pre = (slope*annee_chute + intercept)
    e = 0
    
    if pourcentage == 0:
        return slope*np.asarray(X) + intercept
    
    for i in range(0, len(X)):
        if slope_pre > 1 and e == 0 :      
            list_valeur.append(valeur_pre+slope_pre) 
            valeur_pre = valeur_pre+slope_pre
            slope_pre = slope_pre*(1-pourcentage/100)

        else:        
            e = 1
            list_valeur.append(valeur_pre+slope_pre) 
            valeur_pre = valeur_pre-slope_pre
            slope_pre = slope_pre*(1+pourcentage/100)
     
    return list_valeur

# %%
energie_avec_chute('Monde', 2000, 2010, 2003, 5)
# Out:
# [11254.165024630584,
#  11464.360714285756,
#  11664.04661945817,
#  11853.748229371962,
#  12033.964758790065,
#  12205.170461737263,
#  12367.815879537102,
#  12522.329026446949,
#  12669.116516011303,
#  12808.564631097439]

# %% [markdown]
# Toujours d'après les données de Enerdata, on peut examiner le nombre selon le pourcentage d'énergie consommée pour une région à une année voulu sur notre régression linéaire et à le comparer avec l'énergie consommé par la France en 2017

# %%
def comparaison(P,year, pourcentage):
    FranceMTEP= 243
    
    return str(pourcentage)+"% de la consommation de "+ P +" vaut " + str(int(energy(P, year)*pourcentage/100))+" MTEP en "+str(year)+" soit environs "+str(int(energy(P, year)*pourcentage/(FranceMTEP*100)))+" fois la consommation de la France en 2017 !!! "

# %%
comparaison("Monde", 2018, 100)
# Out:
# '100% de la consommation de Monde vaut 14351 MTEP en 2018 soit environs 59 fois la consommation de la France en 2017 !!! '

# %% [markdown]
# ## 2) Modélisation selon le nombre d'habitant

# %% [markdown]
# Sur cette partie, les données prisent provienent de donnees.banquemondiale
# On recupère cette fois-ci les données sous forme excel.

# %%
energie_par_personne = pd.read_excel("./banquemondiale.xls", index_col=0)

# %% [markdown]
# Nous obtenons un plus large choix de pays mais nous allons nous contenter des pays utilisés pour la partie "Polulation"
# car nous mélangeons nos deux modèles.

# %%
print(energie_par_personne.index)
# Out:
# Index(['Angola', 'Albanie', 'Le monde arabe', 'Émirats arabes unis',
#        'Argentine', 'Australie', 'Autriche', 'Belgique', 'Bénin', 'Bangladesh',
#        ...
#        'États-Unis', 'Venezuela', 'Viet Nam', 'Monde', 'Yémen, Rép. du',
#        'Afrique du Sud', 'Zambie', 'Zimbabwe', 'Asie', 'Afrique'],
#       dtype='object', name='Country Name', length=135)

# %% [markdown]
# Selon le même modèle de régression linéaire que dans la partie 1). Nous faisons une régression linéaire sur nos données afin de prédire le nombre de KWh utilisé par personne à une année et sur un pays voulu.

# %%
Annee2 = [int(i) for i in  energie_par_personne.columns ]

def region_2(P):
    'Sélectionne les données du pays P'
    
    return energie_par_personne.loc[P]

def predict(slope, intercept, x):
    'Fonction après la régression linéaire'
    
    return slope*np.asarray(x) + intercept

def graph2(P):
    """ P est le pays ou une région du monde"""
    
    X = [int(i) for i in energie_par_personne.columns]
    Y = list(region_2(P))
    
    axes = plt.axes()
    axes.grid()
    plt.title(P)
    plt.xlabel('Année')
    plt.ylabel("Consommation d'énergie par personne en KWh")
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()

# %%
graph2('Monde')

# %%
def energy_per_person(P, year):
    """ P est un pays ou une région du monde"""
    
    X = Annee2
    Y = list(region_2(P))
        
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    return slope*year + intercept

# %%
energy_per_person('Europe', 2010)
# Out:
# 3970.692279494142

# %% [markdown]
# On combine ici nos deux modèles afin d'avoir les données de la consomation du pays totale en tep selon le nombre d'habitants.
# Les pays possibles qu'on peut modéliser sont : l'Europe, l'Amérique du Nord, l'Asie, l'Afrique.
#
# Mes données ne me donnaient seulement des parties de ces régions du monde, j'ai estimé alors la consommsation par personne de la région par la somme de la consommation par personne de chaque partie de cette région.
# Je n'avais donc pas assez de données pour l'Amérique du Sud et je ne pouvais pas me contenter que des données sur l'Australie pour l'Océanie.

# %%
Region_possible=["Europe","Amérique du Nord","Asie","Afrique"]

def dict_energie_comsommé_tot(annee_final, pop, n1, m1, probleme1, positif1, fixe1, n2, m2, probleme2, positif2, fixe2,
                              n3, m3, probleme3, positif3, fixe3, n4, m4, probleme4, positif4, fixe4):
    
    
    evo_pop = evolution_pop((annee_final-2017), pop, n1, m1, probleme1, positif1, fixe1, n2, m2, probleme2, 
                            positif2, fixe2, n3, m3, probleme3, positif3, fixe3, n4, m4, probleme4, positif4, fixe4, 
                            0, 0, False, False, False, 0, 0, False, False, False)
    n = 0
    m = 0
    probleme = True
    fixe = True
    positif = True
    Annee = [i for i in range(2017, annee_final)]
    an=2017
    dict_energie = dict()
    
    for i in Region_possible:
        if i == "Europe":
            n = n1
            m = m1
            probleme = probleme1
            positif = positif1
            fixe = fixe1
        if i == "Amérique du Nord":
            n = n2
            m = m2
            probleme = probleme2
            positif = positif2
            fixe = fixe2
        if i == "Asie":
            n = n3
            m = m3
            probleme = probleme3
            positif = positif3
            fixe = fixe3
        if i == "Afrique": 
            n = n4
            m = m4
            probleme = probleme4
            positif = positif4
            fixe = fixe4
            
        dict_energie[i] = []
        an =2017
            
        for e in evo_pop[i]:
            dict_energie[i].append(e*energy_per_person(i, an)*8.5985*10**(-11))
            an = an +1
       
    return dict_energie

# %%
def graph2_bis(annee_final, pop, n1, m1, probleme1, positif1, fixe1, n2, m2, probleme2, positif2, fixe2,
                              n3, m3, probleme3, positif3, fixe3, n4, m4, probleme4, positif4, fixe4):
    """ P est le pays ou une région du monde"""
    X = [i for i in range(2017, annee_final+1)]
    Y = dict_energie_comsommé_tot(annee_final-7, pop, n1, m1, probleme1, positif1, fixe1, n2, m2, probleme2, positif2, 
                                  fixe2, n3, m3, probleme3, positif3, fixe3, n4, m4, probleme4, positif4, fixe4)
                             
    axes = plt.axes()
    axes.grid()
    plt.title('Comparaisons entres plusieurs région')
    plt.xlabel('Année')
    plt.ylabel("Consommation d'énergie en MTEP du pays selon la population")
    plt.plot(X, Y['Europe'], c='r', label='Europe')
    plt.plot(X, Y['Amérique du Nord'], c='g', label='Amérique du Nord')
    plt.plot(X, Y['Asie'], c='b',label='Asie')
    plt.plot(X, Y['Afrique'], c='y', label='Afrique')
    pylab.legend(loc='upper left')
    
    plt.show()

# %% [markdown]
# On obtient donc un graphique qui montre l'évolution de la consommation d'énergie par les régions selon les paramètres de la partie 'Population'.

# %%
graph2_bis(2150, pop, 849400, 50660, True, True, False, 3519842, 100000, True, True, False, 9021686, 438000, True, False, True, 135162, 2455420, True, False, True)

# %% [markdown]
# ## IV) CO2 (Tahar)##

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

pd.read_csv('./CO2_DATA2.csv', sep=' ')
co2_data = pd.read_csv('./CO2_DATA2.csv', sep=' ')

# %% [markdown]
# # I) NIVEAU MONDIAL

# %%
emissions = [float(j.replace(",", "."))*3.664 for j in [i for i in co2_data['Em']]]
land_use = [float(j.replace(",", "."))*3.664 for j in [i for i in co2_data['land-use']]]
Année = [int(i) for i in co2_data['Year']]
ocean_sink = [float(j.replace(",", "."))*3.664 for j in [i for i in co2_data['oc']]]
land_sink = [float(j.replace(",", "."))*3.664 for j in [i for i in co2_data['land']]]

def calcul_co2_y(Le,Lu,L_oc,L_land,list_y):
    
    D = {}
    
    for i in range(0,len(Le)):
        Co2 = (Le[i] + Lu[i] - (L_oc[i] + L_land[i]))
        D[list_y[i]] = Co2
       
    list_Co2 = [i for i in D.values()]
    
    plt.plot(list_y , list_Co2)
    plt.xlabel('Année')
    plt.ylabel('Co2 émis en milliards de tonnes')
    
    return D

# %%
calcul_co2_y(emissions,land_use,ocean_sink,land_sink,Année)
# Out:
# {1959: 9.05008,
#  1960: 5.93568,
#  1961: 9.08672,
#  1962: 6.7783999999999995,
#  1963: 8.75696,
#  1964: 5.569280000000001,
#  1965: 10.369119999999999,
#  1966: 7.437920000000002,
#  1967: 6.668480000000001,
#  1968: 4.543359999999998,
#  1969: 12.2744,
#  1970: 13.30032,
#  1971: 6.265440000000002,
#  1972: 11.065279999999998,
#  1973: 9.01344,
#  1974: 0.10992000000000246,
#  1975: 6.228799999999996,
#  1976: 5.239519999999999,
#  1977: 10.662239999999999,
#  1978: 5.605920000000001,
#  1979: 12.860640000000004,
#  1980: 14.655999999999999,
#  1981: 6.924959999999999,
#  1982: 10.58896,
#  1983: 14.802560000000001,
#  1984: 6.521919999999998,
#  1985: 7.8409599999999955,
#  1986: 10.112640000000003,
#  1987: 17.36736,
#  1988: 12.054560000000002,
#  1989: 7.1448,
#  1990: 11.724799999999998,
#  1991: 12.640799999999997,
#  1992: 11.1752,
#  1993: 8.317279999999997,
#  1994: 14.69264,
#  1995: 14.17968,
#  1996: 9.08672,
#  1997: 12.4576,
#  1998: 14.839200000000002,
#  1999: 7.98752,
#  2000: 7.840959999999999,
#  2001: 14.509439999999998,
#  2002: 19.71232,
#  2003: 15.095680000000002,
#  2004: 11.871360000000003,
#  2005: 18.64976,
#  2006: 14.61936,
#  2007: 15.022399999999998,
#  2008: 13.556799999999996,
#  2009: 17.9536,
#  2010: 19.345920000000003,
#  2011: 16.52464,
#  2012: 24.145760000000003,
#  2013: 20.37184,
#  2014: 18.539839999999998,
#  2015: 26.673919999999995,
#  2016: 21.28784000000001,
#  2017: 18.210079999999998}

# %%
def predict_em(slope, intercept, x):
    
    return slope*np.asarray(x) + intercept

def graph_em():
    
    X = Année
    Y = emissions
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre Emissions')
    plt.xlabel('Année')
    plt.ylabel('Emissions de Co2 en Mt')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict_em(slope, intercept, X), c='r')
    plt.show()

# %%
graph_em()

# %%
def predict_land_u(slope, intercept, x):
    
    return slope*np.asarray(x) + intercept

def graph_land_u():
    
    X = Année
    Y = land_use
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre land-use')
    plt.xlabel('Année')
    plt.ylabel('Utilisations Terres en Mt de Carbone')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict_land_u(slope, intercept, X), c='r')
    plt.show()

# %%
graph_land_u()

# %%
def predict_oc(slope, intercept, x):
    
    return slope*np.asarray(x) + intercept

def graph_oc():
    
    X = Année
    Y = ocean_sink
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre ocean_sink')
    plt.xlabel('Année')
    plt.ylabel('Absoption en Mt de carbone')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict_oc(slope, intercept, X), c='r')
    plt.show()
    print(predict_oc(slope, intercept, 2050))

# %%
graph_oc()
# Out:
# 12.816153772063132

# %%
def predict_land_s(slope, intercept, x):
    
    return slope*np.asarray(x) + intercept

def graph_land_s():
    
    X = Année
    Y = land_sink 
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre land_sink ')
    plt.xlabel('Année')
    plt.ylabel('Absoption en Mt de carbone')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict_land_s(slope, intercept, X), c='r')
    plt.show()

# %%
graph_land_s()

# %%
def predict_em(year):
    
    X = Année 
    Y = emissions    
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    
    return slope*year + intercept

def predict_land_u(year):
    
    X = Année 
    Y = land_use    
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    
    return slope*year + intercept

def predict_oc(year):
    
    X = Année 
    Y = ocean_sink  
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    
    return slope*year + intercept

def predict_land_s(year):
    
    X = Année
    Y = land_sink     
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    
    return slope*year + intercept



def list_final(annee_final):
    
    X_Annee = [i for i in range(1959,annee_final)]
    Y_final = []
    
    for i in X_Annee:
        Y_final.append(predict_em(i) + predict_land_u(i) - predict_oc(i) - predict_land_s(i))
        
    return Y_final

def graph_final(annee_final):
    
    D = {}
    
    for i in range(0,len(emissions)):
        C = emissions[i] + land_use[i] - (ocean_sink[i] + land_sink[i])
        D[Année[i]] = C
       
    list_C = [i for i in D.values()]
    
    X_Annee = [i for i in range(1959,annee_final)]
    
    axes = plt.axes()
    axes.grid()
    plt.plot(Année , list_C)
    plt.xlabel('Année')
    plt.ylabel('Co2 émis en milliards de tonnes')
    
    plt.plot(X_Annee , list_final(annee_final), c='r')
    plt.show()
    
def valeur(annee_final):
    
    X_Annee = [i for i in range(1959,annee_final)]
    D = dict()
    
    for i in range(0, len(X_Annee)):
        
        D[X_Annee[i]] = list_final(annee_final)[i]
                   
    return D

# %%
graph_final(2100)

# %%
predict_em(2010) + predict_land_u(2010) - predict_oc(2010) - predict_land_s(2010)
# Out:
# 17.00526000701347

# %%
predict_em(2100) + predict_land_u(2100)
# Out:
# 77.10558004441847

# %% [markdown]
# # II ) NIVEAU CONTINENTAL :

# %%
pd.read_csv('terri.csv', sep=' ')
terri = pd.read_csv('terri.csv', sep=' ')
pd.read_csv('land.csv', sep=' ')
land = pd.read_csv('land.csv', sep=' ')

NA_l = [ float(j) for j in [i.replace(",", ".") for i in land['N/A']]]
NA_t = [ float(j) for j in [i.replace(",", ".") for i in terri['N/A']]]
SA_l = [ float(j) for j in [i.replace(",", ".") for i in land['S/A']]]
SA_t = [ float(j) for j in [i.replace(",", ".") for i in terri['S/A']]]
Asie_l = [ float(j) for j in [i.replace(",", ".") for i in land['Asie']]]
Asie_t = [ float(j) for j in [i.replace(",", ".") for i in terri['Asie']]]
EU_l = [ float(j) for j in [i.replace(",", ".") for i in land['Europe']]]
EU_t = [ float(j) for j in [i.replace(",", ".") for i in terri['Europe']]]
Oce_l = [ float(j) for j in [i.replace(",", ".") for i in land['Oceanie']]]
Oce_t = [ float(j) for j in [i.replace(",", ".") for i in terri['Oceanie']]]
Afri_l = [ float(j) for j in [i.replace(",", ".") for i in land['Afrique']]]
Afri_t = [ float(j) for j in [i.replace(",", ".") for i in terri['Afrique']]]
Année_l = [ j for j in range(1960,2011)]
Année_t = [ j for j in range(1960,2018)]

# %% [markdown]
# 1. AMERIQUE DU NORD

# %%
def predict(slope, intercept, x):
    
    return slope*np.asarray(x) + intercept

def graph_NA_l():
    
    X = Année_l
    Y = NA_l
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre NA_l')
    plt.xlabel('Année')
    plt.ylabel('Emission land NA en Millions de tonne de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()
    
def graph_NA_t():
    
    X = Année_t
    Y = NA_t
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre NA_t')
    plt.xlabel('Année')
    plt.ylabel('Emission terri NA en Millions de tonne de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()

# %%
graph_NA_l()
graph_NA_t()

# %%
def x(an):
    
    X = Année_l
    Y = NA_l
    
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    
    return slope*an + intercept

NA_l_bis = [x(i) for i in range(2011,2018)]
NA_l_bis2 = NA_l + NA_l_bis

NA_Em = [NA_l_bis2[i]+NA_t[i] for i in range(0,len(NA_t))]

NA = [(NA_Em[i]-NA_Em[i]*0.5)/1000 for i in range(0,len(Année_t))]

def graph_NA():
    
    X = Année_t
    Y = NA
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre NA')
    plt.xlabel('Année')
    plt.ylabel('Emission de NA en Mt de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()
    
graph_NA()

# %% [markdown]
# 2. AMERIQUE DU SUD

# %%
def predict(slope, intercept, x):
    
    return slope*np.asarray(x) + intercept

def graph_SA_l():
    
    X = Année_l
    Y = SA_l
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre SA_l')
    plt.xlabel('Année')
    plt.ylabel('Emission land SA en Millions de tonne de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()
    
def graph_SA_t():
    
    X = Année_t
    Y = SA_t
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre SA_t')
    plt.xlabel('Année')
    plt.ylabel('Emission terri SA en Millions de tonne de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()

# %%
graph_SA_l()
graph_SA_t()

# %%
def x(an):
    
    X = Année_l
    Y = SA_l
    
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    
    return slope*an + intercept

SA_l_bis = [x(i) for i in range(2011,2018)]
SA_l_bis2 = SA_l + SA_l_bis

SA_Em = [SA_l_bis2[i]+SA_t[i] for i in range(0,len(NA_t))]

SA = [(SA_Em[i]-SA_Em[i]*0.5)/1000 for i in range(0,len(Année_t))]

def graph_SA():
    
    X = Année_t
    Y = SA
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre SA')
    plt.xlabel('Année')
    plt.ylabel('Emission de SA en Mt de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()
graph_SA()

# %% [markdown]
# 3. ASIE

# %%
def predict(slope, intercept, x):
    
    return slope*np.asarray(x) + intercept

def graph_Asie_l():
    
    X = Année_l
    Y = Asie_l
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre Asie_l')
    plt.xlabel('Année')
    plt.ylabel('Emission land Asie en Millions de tonne de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()
    
def graph_Asie_t():
    
    X = Année_t
    Y = Asie_t
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre Asie_t')
    plt.xlabel('Année')
    plt.ylabel('Emission terri Asie en Millions de tonne de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()

# %%
graph_Asie_l()
graph_Asie_t()

# %%
def x(an):
    
    X = Année_l
    Y = Asie_l
    
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    
    return slope*an + intercept

Asie_l_bis = [x(i) for i in range(2011,2018)]
Asie_l_bis2 = Asie_l + Asie_l_bis

Asie_Em = [Asie_l_bis2[i]+Asie_t[i] for i in range(0,len(NA_t))]

Asie = [(Asie_Em[i]-Asie_Em[i]*0.5)/1000 for i in range(0,len(Année_t))]

def graph_Asie():
    
    X = Année_t
    Y = Asie
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre Asie')
    plt.xlabel('Année')
    plt.ylabel('Emission de Asie en Mt de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()
    
graph_Asie()

# %% [markdown]
# 4. EUROPE

# %%
def predict(slope, intercept, x):
    
    return slope*np.asarray(x) + intercept

def graph_EU_l():
    
    X = Année_l
    Y = EU_l
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre EU_l')
    plt.xlabel('Année')
    plt.ylabel('Emission land EU en Millions de tonne de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()
    
def graph_EU_t():
    
    X = Année_t
    Y = EU_t
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre EU_t')
    plt.xlabel('Année')
    plt.ylabel('Emission terri EU en Millions de tonne de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()

# %%
graph_EU_l()
graph_EU_t()

# %%
def x(an):
    
    X = Année_l
    Y = EU_l
    
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    
    return slope*an + intercept

EU_l_bis = [x(i) for i in range(2011,2018)]
EU_l_bis2 = EU_l + EU_l_bis

EU_Em = [EU_l_bis2[i]+EU_t[i] for i in range(0,len(NA_t))]

EU = [(EU_Em[i]-NA_Em[i]*0.5)/1000 for i in range(0,len(Année_t))]

def graph_EU():
    
    X = Année_t
    Y = EU
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre EU')
    plt.xlabel('Année')
    plt.ylabel('Emission de EU en Mt de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()
    
graph_EU()

# %% [markdown]
# 5. OCEANIE

# %%
def predict(slope, intercept, x):
    
    return slope*np.asarray(x) + intercept

def graph_Oce_l():
    
    X = Année_l
    Y = Oce_l
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre Oce_l')
    plt.xlabel('Année')
    plt.ylabel('Emission land Oce en Millions de tonne de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()
    
def graph_Oce_t():
    
    X = Année_t
    Y = Oce_t
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre Oce_t')
    plt.xlabel('Année')
    plt.ylabel('Emission terri Oce en Millions de tonne de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()

# %%
graph_Oce_l()
graph_Oce_t()

# %%
def x(an):
    
    X = Année_l
    Y = Oce_l
    
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    
    return slope*an + intercept

Oce_l_bis = [x(i) for i in range(2011,2018)]
Oce_l_bis2 = Oce_l + Oce_l_bis

Oce_Em = [Oce_l_bis2[i]+Oce_t[i] for i in range(0,len(NA_t))]

Oce = [(Oce_Em[i]-Oce_Em[i]*0.5)/1000 for i in range(0,len(Année_t))]

def graph_Oce():
    
    X = Année_t
    Y = Oce
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre Oce')
    plt.xlabel('Année')
    plt.ylabel('Emission de Oce en Mt de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()
    
graph_Oce()

# %% [markdown]
# 6. AFRIQUE

# %%
def predict(slope, intercept, x):
    
    return slope*np.asarray(x) + intercept

def graph_Afri_l():
    
    X = Année_l
    Y = Afri_l
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre Afri_l')
    plt.xlabel('Année')
    plt.ylabel('Emission land Afri en Millions de tonne de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()
    
def graph_Afri_t():
    
    X = Année_t
    Y = Afri_t
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre Afri_t')
    plt.xlabel('Année')
    plt.ylabel('Emission terri Afri en Millions de tonne de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()

# %%
graph_Afri_l()
graph_Afri_t()

# %%
def x(an):
    
    X = Année_l
    Y = Afri_l
    
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    
    return slope*an + intercept

Afri_l_bis = [x(i) for i in range(2011,2018)]
Afri_l_bis2 = Afri_l + Afri_l_bis

Afri_Em = [Afri_l_bis2[i]+Afri_t[i] for i in range(0,len(NA_t))]

Afri = [(Afri_Em[i]-Afri_Em[i]*0.5)/1000 for i in range(0,len(Année_t))]

def graph_Afri():
    
    X = Année_t
    Y = Afri
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre Afri')
    plt.xlabel('Année')
    plt.ylabel('Emission de Afri en Mt de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()
    
graph_Afri()

# %% [markdown]
# Vérifiction par rapport au code mondial :

# %%
def graph_Mondiale():
    
    X = Année_t
    Y = [NA[i]+SA[i]+EU[i]+Afri[i]+Oce[i]+Asie[i] for i in range(0,len(NA))]
    
    axes = plt.axes()
    axes.grid()
    plt.title('Approximation du parametre Mondiale')
    plt.xlabel('Année')
    plt.ylabel('Emission Mondiale en Mt de CO2')
    plt.scatter(X,Y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    plt.plot(X, predict(slope, intercept, X), c='r')
    plt.show()
graph_Mondiale()

# %% [markdown]
# ## V) Assemblage de tous les paramètres ##

# %% [markdown]
# ### 1) PIB/POP

# %%
def PIB_hab_continental(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6,cfc,fbcfc,vsc,continents,xc,mc):
    D={"Europe":[],"Amérique du Nord":[],"Asie":[],"Afrique":[],"Amérique du Sud":[],"Océanie":[]}
    popu=evolution_pop(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6)
    PIB=evolution_PIB(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6,cfc,fbcfc,vsc,continents,xc,mc)
    for i in range(0,a+1):
        for k in continents:
            if popu[k][i]!=0:
                D[k].append((PIB[k][i])/(popu[k][i]))
            else:
                D[k].append(0)
    return D

# %%
PIB_hab_continental(5,pop,1235000,9845500,False,False,False,1536852,6548213,False,True,True,4561237,5462137,False,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,False,True,False,cfc,fbcfc,vsc,continents,xc,mc)
# Out:
# {'Afrique': [2623.732134226698,
#   2627.128132336445,
#   2630.444770380301,
#   2633.67136487424,
#   2636.7963935647736,
#   2639.813718791388],
#  'Amérique du Nord': [44556.59152350247,
#   44570.60712313659,
#   44583.867598988014,
#   44596.55344083365,
#   44608.91335920695,
#   44621.12188950233],
#  'Amérique du Sud': [7415.20137061234,
#   7416.001152864454,
#   7416.77609422712,
#   7417.526037003367,
#   7418.250615031668,
#   7418.949757432285],
#  'Asie': [5655.909112114336,
#   5654.528526985675,
#   5653.176923692647,
#   5651.859539057907,
#   5650.583290174893,
#   5649.353012045947],
#  'Europe': [24064.272217038022,
#   24063.097771461646,
#   24062.198857284293,
#   24061.513137753238,
#   24060.936674185552,
#   24060.39632702671],
#  'Océanie': [42181.61337177103,
#   42193.60822626882,
#   42204.967271810274,
#   42215.77609244444,
#   42226.16307103022,
#   42236.21610185113]}

# %%
L_annee=[i for i in range(2010,2100)]

def plot_PIB_hab_continental(L1,L2,L3,L4,L5,L6):
    plt.figure()
    plt.plot(L_annee,L1)
    plt.plot(L_annee,L2)
    plt.plot(L_annee,L3)
    plt.plot(L_annee,L4)
    plt.plot(L_annee,L5)
    plt.plot(L_annee,L6)
    plt.legend([continent for continent in continents])
    plt.xlabel("Année")
    plt.ylabel("PIB/hab")
    plt.show()
    return

# %%
PIB_hab=PIB_hab_continental(89,pop,1235000,98455,False,True,False,1536852,65413,False,True,True,4561237,54637,False,True,True,7531596,67821,False,True,False,300,60,False,True,False,300,60,False,True,False,cfc,fbcfc,vsc,continents,xc,mc)
L1=PIB_hab["Europe"]
L2=PIB_hab["Amérique du Nord"]
L3=PIB_hab["Asie"]
L4=PIB_hab["Afrique"]
L5=PIB_hab["Amérique du Sud"]
L6=PIB_hab["Océanie"]

# %%
plot_PIB_hab_continental(L1,L2,L3,L4,L5,L6)

# %%
def PIB_hab(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6,cfc,fbcfc,vsc,continents,xc,mc):
    L=[]
    Lpop=[]
    LPIB=[]
    popu=evolution_pop(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6)
    PIB=evolution_PIB(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6,cfc,fbcfc,vsc,continents,xc,mc)
    for i in range(0,a+1):
        s=0
        pop1=0
        for k in continents:
            s=s+PIB[k][i]
            pop1=pop1+popu[k][i]
        L.append(s/pop1)
    return L

# %%
PIB_hab(15,pop,1235000,9845500,False,False,False,1536852,6548213,False,True,True,4561237,5462137,False,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,False,True,False,cfc,fbcfc,vsc,continents,xc,mc)
# Out:
# [9428.576885570401,
#  9395.575926319645,
#  9361.60417351686,
#  9327.16638465497,
#  9292.971613489774,
#  9259.521294595306,
#  9226.909325603578,
#  9170.830990633172,
#  9125.283631633634,
#  9104.169443182573,
#  9104.839535178886,
#  9091.764387770821,
#  9068.836292834978,
#  9093.953972405434,
#  9082.452539669755,
#  9068.295445166546]

# %%
def plot_PIB_hab_mondial(L):
    plt.figure()
    plt.plot(L_annee,L)
    plt.xlabel("Année")
    plt.ylabel("PIB/hab")
    plt.show()
    return

# %%
L=PIB_hab(89,pop,1235000,9845500,False,False,False,1536852,6548213,False,True,True,4561237,5462137,False,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,False,True,False,cfc,fbcfc,vsc,continents,xc,mc)

# %%
plot_PIB_hab_mondial(L)

# %%
L[49]
# Out:
# 8524.359285044793

# %%
L[0]-L[49]
# Out:
# 904.2176005256078

# %%
def PIB_POP_bis(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6):
    L=[]
    popu=evolution_pop(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6)
    PIB=futur_mondial(2010+a)
    for i in range(0,a):
        pop1=0
        for k in continents:
            pop1=pop1+popu[k][i]
        L.append(PIB[i]/pop1)
    return L

# %%
L=PIB_POP_bis(90,pop,1235000,9845500,False,False,False,1536852,6548213,False,True,True,4561237,5462137,False,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,False,True,False)

# %%
plot_PIB_hab_mondial(L)

# %% [markdown]
# ### 2) TEP/PIB

# %%
def TEP_PIB(P,a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6,cfc,fbcfc,vsc,continents,xc,mc):
    PIB=evolution_PIB_mondial(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6,cfc,fbcfc,vsc,continents,xc,mc)
    TEP=[]
    tep_pib=[]
    for i in range(0,a+1):
        TEP.append(energy(P,2010+i))
    for x in range(0,a+1):
        tep_pib.append(TEP[x]/PIB[x])
    return tep_pib

# %%
TEP_PIB('Monde',89,pop,1235000,9845500,False,False,False,1536852,6548213,False,True,True,4561237,5462137,False,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,False,True,False,cfc,fbcfc,vsc,continents,xc,mc)
# Out:
# [1.9256517732437843e-10,
#  1.942930292521086e-10,
#  1.960182406108699e-10,
#  1.9773803580395244e-10,
#  1.994461365125723e-10,
#  2.0113869542632102e-10,
#  2.0281663786174957e-10,
#  2.0407398726454795e-10,
#  2.0551514250546557e-10,
#  2.0731743999152384e-10,
#  2.0778716463055317e-10,
#  2.0881467885813663e-10,
#  2.0886962326392482e-10,
#  2.0867807777550976e-10,
#  2.0993574763271253e-10,
#  2.0974938482927775e-10,
#  2.1003176526023138e-10,
#  2.0997937669782997e-10,
#  2.114094922460138e-10,
#  2.1183216585415172e-10,
#  2.1216788645593067e-10,
#  2.1215149095079015e-10,
#  2.1191874047248334e-10,
#  2.1379958590786587e-10,
#  2.137871319486861e-10,
#  2.129109737216623e-10,
#  2.134357404250319e-10,
#  2.1444956900262586e-10,
#  2.1554454595436888e-10,
#  2.1530277875936303e-10,
#  2.1343506175167482e-10,
#  2.1472597072778111e-10,
#  2.1453160404212976e-10,
#  2.15547102425818e-10,
#  2.146291128642195e-10,
#  2.1479636830871034e-10,
#  2.15945973581877e-10,
#  2.1394973191488376e-10,
#  2.1745756206188872e-10,
#  2.1661954727820072e-10,
#  2.148976063939401e-10,
#  2.1645560712540575e-10,
#  2.1474452258259637e-10,
#  2.1449004147037043e-10,
#  2.178352367115649e-10,
#  2.1608065802643266e-10,
#  2.156065449962185e-10,
#  2.1627720116338144e-10,
#  2.153411819761334e-10,
#  2.1435115022835892e-10,
#  2.153568381518999e-10,
#  2.1564686749503764e-10,
#  2.1611827005167524e-10,
#  2.1356991074713037e-10,
#  2.155509633451565e-10,
#  2.1481733408301348e-10,
#  2.137794740576726e-10,
#  2.123904733664895e-10,
#  2.115934957751262e-10,
#  2.128308563286678e-10,
#  2.1378900430367484e-10,
#  2.1286004925124512e-10,
#  2.1299548397908302e-10,
#  2.1096072081351695e-10,
#  2.1379875255078044e-10,
#  2.1332532091811624e-10,
#  2.1307693719635359e-10,
#  2.1241636548940388e-10,
#  2.073722728507846e-10,
#  2.123833027801216e-10,
#  2.071297287710658e-10,
#  2.1045817474489228e-10,
#  2.095751918579211e-10,
#  2.0952937543454414e-10,
#  2.081699705885206e-10,
#  2.1005052579806665e-10,
#  2.1014405595574884e-10,
#  2.0482836210163499e-10,
#  2.045106744955001e-10,
#  2.0527816321367122e-10,
#  2.1021406359774534e-10,
#  2.0593993353101174e-10,
#  2.0557384093061367e-10,
#  1.9899022327238174e-10,
#  2.0442012329166888e-10,
#  2.0525002279421686e-10,
#  2.0257964212858003e-10,
#  1.9755253978798797e-10,
#  2.0170211764034886e-10,
#  1.9838644982079453e-10]

# %%
def plot_TEP_PIB(L):
    plt.figure()
    plt.plot(L_annee,L)
    plt.xlabel("Année")
    plt.ylabel("TEP/PIB")
    plt.show()
    return

# %%
L=TEP_PIB('Monde',89,pop,1235000,9845500,False,False,False,1536852,6548213,False,True,True,4561237,5462137,False,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,False,True,False,cfc,fbcfc,vsc,continents,xc,mc)
plot_TEP_PIB(L)

# %%
def TEP_PIBbis(P,a):
    PIB=futur_mondial(2010+a)
    TEP=[]
    tep_pib=[]
    for i in range(0,a):
        TEP.append(energy(P,2010+i))
    for x in range(0,a):
        tep_pib.append(TEP[x]/PIB[x])
    return tep_pib

# %%
L=TEP_PIBbis('Monde',90)

# %%
plot_TEP_PIB(L)

# %%
def TEP_PIB_4continents(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6,cfc,fbcfc,vsc,continents,xc,mc):
    D={'Europe':[],'Amérique du Nord':[],'Asie':[],'Afrique':[]}
    TEP=dict_energie_comsommé_tot(2010+a, pop, n1, m1, probleme1, positif1, fixe1, n2, m2, probleme2, positif2, fixe2,n3, m3, probleme3, positif3, fixe3, n4, m4, probleme4, positif4, fixe4)
    PIB=evolution_PIB(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6,cfc,fbcfc,vsc,continents,xc,mc)
    for i in range(0,a+1):
        for c in TEP:
            D[c].append((TEP[c][i])/(PIB[c][i]))
    return D

# %%
TEP_PIB_4continents(89,pop,1235000,9845500,False,False,False,1536852,6548213,False,True,True,4561237,5462137,False,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,False,True,False,cfc,fbcfc,vsc,continents,xc,mc)
# Out:
# {'Afrique': [2.801236341877892e-10,
#   2.8344382052109557e-10,
#   2.8676408551693856e-10,
#   2.900859057524921e-10,
#   2.934108979650977e-10,
#   2.967401246019144e-10,
#   3.0007384913170486e-10,
#   3.0331169307507907e-10,
#   3.066542032344469e-10,
#   3.099975461397125e-10,
#   3.1334177955467997e-10,
#   3.166869577397127e-10,
#   3.2003313162137845e-10,
#   3.2338034892197323e-10,
#   3.2672865430423287e-10,
#   3.300780895262873e-10,
#   3.334286935240865e-10,
#   3.3678050258327704e-10,
#   3.401335504312994e-10,
#   3.4348786835124054e-10,
#   3.4684348529900974e-10,
#   3.502004279984854e-10,
#   3.535587210474908e-10,
#   3.5691838700936407e-10,
#   3.602794465085108e-10,
#   3.636419183031968e-10,
#   3.670058193935092e-10,
#   3.703711650763522e-10,
#   3.7373796904440957e-10,
#   3.771062434449873e-10,
#   3.8047599895725646e-10,
#   3.8384724486308083e-10,
#   3.8721998909739865e-10,
#   3.9059423832990457e-10,
#   3.939699980173961e-10,
#   3.973472724603374e-10,
#   4.0072606485578614e-10,
#   4.041063773533369e-10,
#   4.074882111098935e-10,
#   4.1087156633177417e-10,
#   4.142564423260239e-10,
#   4.1764283754259783e-10,
#   4.2103074962183487e-10,
#   4.244201754287431e-10,
#   4.278111111001718e-10,
#   4.3120355208133305e-10,
#   4.345974931604174e-10,
#   4.379929285015492e-10,
#   4.4138985168598715e-10,
#   4.4478825573854216e-10,
#   4.4818813316247363e-10,
#   4.5158947596327894e-10,
#   4.5499227568706283e-10,
#   4.5839652343627075e-10,
#   4.6180220990634963e-10,
#   4.6520932540713776e-10,
#   4.686178598866383e-10,
#   4.720278029537424e-10,
#   4.75439143901263e-10,
#   4.78851871729001e-10,
#   4.822659751631075e-10,
#   4.856814426736646e-10,
#   4.89098262498381e-10,
#   4.925164226550754e-10,
#   4.959359109626337e-10,
#   4.993567150566502e-10,
#   5.027788224055571e-10,
#   5.062022203260939e-10,
#   5.096268959948183e-10,
#   5.130528364678576e-10,
#   5.164800286880739e-10,
#   5.199084595028022e-10,
#   5.233381156722789e-10,
#   5.26768983883998e-10,
#   5.30201050761577e-10,
#   5.336343028775792e-10,
#   5.370687267625944e-10,
#   5.405043089137485e-10,
#   5.439410358065624e-10,
#   5.473788939002704e-10,
#   5.508178696503054e-10,
#   5.542579495134467e-10,
#   5.576991199558158e-10,
#   5.611413674606941e-10,
#   5.645846785352843e-10,
#   5.680290397174516e-10,
#   5.714744375808212e-10,
#   5.749208587423438e-10,
#   5.783682898662758e-10,
#   5.818167176715963e-10],
#  'Amérique du Nord': [2.943731280536068e-11,
#   2.9694918569100144e-11,
#   2.995286967894367e-11,
#   3.021105666028914e-11,
#   3.04693194113185e-11,
#   3.072754333715997e-11,
#   3.098570682482745e-11,
#   3.125007998919311e-11,
#   3.1508310949631664e-11,
#   3.176646731530903e-11,
#   3.2024550173662284e-11,
#   3.228256059624013e-11,
#   3.254049965100627e-11,
#   3.279836838129293e-11,
#   3.305616782714043e-11,
#   3.331389900748102e-11,
#   3.357156293815417e-11,
#   3.3829160617237876e-11,
#   3.408669303405788e-11,
#   3.43441611606542e-11,
#   3.460156596349869e-11,
#   3.4858908394977385e-11,
#   3.511618939643767e-11,
#   3.537340989555431e-11,
#   3.563057081484025e-11,
#   3.588767306063654e-11,
#   3.614471752617024e-11,
#   3.6401705102561414e-11,
#   3.665863666528105e-11,
#   3.691551307448769e-11,
#   3.717233518851048e-11,
#   3.742910385061353e-11,
#   3.768581989708948e-11,
#   3.794248414957067e-11,
#   3.819909742044569e-11,
#   3.8455660520551646e-11,
#   3.871217423892932e-11,
#   3.8968639360843466e-11,
#   3.922505666521876e-11,
#   3.9481426917308336e-11,
#   3.973775087384844e-11,
#   3.9994029283157916e-11,
#   4.0250262882851954e-11,
#   4.0506452404765993e-11,
#   4.076259856791703e-11,
#   4.10187020880908e-11,
#   4.127476366621114e-11,
#   4.1530783997862415e-11,
#   4.178676377101051e-11,
#   4.204270366384115e-11,
#   4.229860434716417e-11,
#   4.255446648228697e-11,
#   4.2810290723375085e-11,
#   4.306607771535952e-11,
#   4.332182809840294e-11,
#   4.3577542501486857e-11,
#   4.383322155111376e-11,
#   4.4088865856543505e-11,
#   4.4344476028986565e-11,
#   4.4600052668966194e-11,
#   4.485559636860361e-11,
#   4.5111107713788134e-11,
#   4.5366587282236456e-11,
#   4.5622035643640794e-11,
#   4.587745336570259e-11,
#   4.613284100428126e-11,
#   4.638819911142377e-11,
#   4.6643528227688735e-11,
#   4.6898828891917864e-11,
#   4.71541016336101e-11,
#   4.74093469768551e-11,
#   4.766456544037634e-11,
#   4.791975753392992e-11,
#   4.817492376212619e-11,
#   4.843006462268048e-11,
#   4.868518061007623e-11,
#   4.8940272206747277e-11,
#   4.919533989560747e-11,
#   4.945038414778853e-11,
#   4.970540543493147e-11,
#   4.9960404217154946e-11,
#   5.0215380950097e-11,
#   5.04703360849408e-11,
#   5.0725270068439953e-11,
#   5.0980183338071925e-11,
#   5.1235076327122994e-11,
#   5.148994946629998e-11,
#   5.174480317736629e-11,
#   5.199963787807734e-11,
#   5.225445398065141e-11],
#  'Asie': [5.7975126608884677e-11,
#   5.923572403777103e-11,
#   6.049662703460754e-11,
#   6.175775919875743e-11,
#   6.301902063501325e-11,
#   6.428032886493896e-11,
#   6.554164938861177e-11,
#   6.681119731302803e-11,
#   6.807162564837337e-11,
#   6.933240007616755e-11,
#   7.059351595547157e-11,
#   7.185496869683944e-11,
#   7.311675376022085e-11,
#   7.437886665569844e-11,
#   7.564130294170441e-11,
#   7.690405822671333e-11,
#   7.81671281658858e-11,
#   7.9430508463395e-11,
#   8.06941948703392e-11,
#   8.19581831845483e-11,
#   8.322246925039642e-11,
#   8.448704895861087e-11,
#   8.575191824545726e-11,
#   8.701707309224278e-11,
#   8.828250952482352e-11,
#   8.954822361373422e-11,
#   9.08142114736976e-11,
#   9.208046926251453e-11,
#   9.334699318089429e-11,
#   9.461377947289652e-11,
#   9.588082442452328e-11,
#   9.714812436355547e-11,
#   9.841567565907957e-11,
#   9.968347472222864e-11,
#   1.0095151800359026e-10,
#   1.0221980199456108e-10,
#   1.0348832322687587e-10,
#   1.0475707827124615e-10,
#   1.0602606373780083e-10,
#   1.0729527627503818e-10,
#   1.0856471257055033e-10,
#   1.098343693493957e-10,
#   1.111042433742427e-10,
#   1.1237433144521455e-10,
#   1.1364463039972879e-10,
#   1.1491513711091084e-10,
#   1.161858484888755e-10,
#   1.1745676147886823e-10,
#   1.1872787306252857e-10,
#   1.1999918025549215e-10,
#   1.2127068010920605e-10,
#   1.2254236970882812e-10,
#   1.2381424617392087e-10,
#   1.250863066577517e-10,
#   1.263585483471482e-10,
#   1.276309684615479e-10,
#   1.2890356425419204e-10,
#   1.3017633300931714e-10,
#   1.3144927204440997e-10,
#   1.3272237870795043e-10,
#   1.3399565038058408e-10,
#   1.3526908447342264e-10,
#   1.3654267842893997e-10,
#   1.3781642972005984e-10,
#   1.390903358490176e-10,
#   1.4036439434948568e-10,
#   1.416386027831806e-10,
#   1.4291295874246578e-10,
#   1.441874598475029e-10,
#   1.4546210374783976e-10,
#   1.4673688812129545e-10,
#   1.480118106738299e-10,
#   1.4928686913917151e-10,
#   1.50562061278223e-10,
#   1.5183738487963074e-10,
#   1.5311283775871852e-10,
#   1.543884177578193e-10,
#   1.556641227450053e-10,
#   1.5693995061532194e-10,
#   1.5821589928907495e-10,
#   1.594919667123815e-10,
#   1.6076815085659666e-10,
#   1.620444497181877e-10,
#   1.6332086131817496e-10,
#   1.645973837024376e-10,
#   1.6587401494115108e-10,
#   1.6715075312824456e-10,
#   1.6842759638149062e-10,
#   1.697045428421696e-10,
#   1.7098159067494584e-10],
#  'Europe': [1.4960064779897942e-11,
#   1.5071118549845744e-11,
#   1.5182009312581068e-11,
#   1.5292772859631878e-11,
#   1.540347277562893e-11,
#   1.5514154708245295e-11,
#   1.5624825270598072e-11,
#   1.5737821236295504e-11,
#   1.584329643870744e-11,
#   1.596067475842625e-11,
#   1.6184382513764866e-11,
#   1.630409563606585e-11,
#   1.6360604708234572e-11,
#   1.651775177512474e-11,
#   1.681375702683958e-11,
#   1.6629271491796657e-11,
#   1.6926031930726942e-11,
#   1.6980259658196483e-11,
#   1.6978843033213625e-11,
#   1.724390211314969e-11,
#   1.7207265804461188e-11,
#   1.7279280185458965e-11,
#   1.746602246073064e-11,
#   1.796000843315274e-11,
#   1.7644677923683298e-11,
#   1.797123702581895e-11,
#   1.7842126420755577e-11,
#   1.8126346271994415e-11,
#   1.7852654307408965e-11,
#   1.875534359396417e-11,
#   1.8467740289935654e-11,
#   1.869953306438976e-11,
#   1.946182338584889e-11,
#   1.8967035326690076e-11,
#   1.867635423303264e-11,
#   1.9339296844243283e-11,
#   1.9626330910012675e-11,
#   1.977612014551525e-11,
#   1.9394711939334742e-11,
#   1.9857427284581425e-11,
#   1.9673928511525706e-11,
#   1.9376624722371347e-11,
#   1.9579416453806513e-11,
#   1.951674428773795e-11,
#   1.9767990373275546e-11,
#   1.952965022715147e-11,
#   2.1370022814977918e-11,
#   2.0322154893303634e-11,
#   2.0693583633691217e-11,
#   2.0902088879443952e-11,
#   2.2083304148954336e-11,
#   2.2458367858675443e-11,
#   2.1688440552995177e-11,
#   2.1251742519942335e-11,
#   2.0222361028746793e-11,
#   2.2021693130889926e-11,
#   2.122125546121392e-11,
#   2.16181042642437e-11,
#   2.1056816790663962e-11,
#   2.094717265668716e-11,
#   2.2247140568446657e-11,
#   2.295158954299004e-11,
#   2.2721235216811198e-11,
#   2.2755931159637497e-11,
#   2.3684139882638324e-11,
#   2.2888871655807132e-11,
#   2.4072813064623876e-11,
#   2.4151255209086065e-11,
#   2.365756004356803e-11,
#   2.1314898751495986e-11,
#   2.38365972921203e-11,
#   2.3771626169942687e-11,
#   2.142814943065543e-11,
#   2.202483348412979e-11,
#   2.1641517730744002e-11,
#   2.2046425230985125e-11,
#   2.4555112542885146e-11,
#   2.586347944495985e-11,
#   2.2944515493624534e-11,
#   2.2909520469220186e-11,
#   2.496787064295157e-11,
#   2.5136975905095412e-11,
#   2.6021381380187677e-11,
#   2.6879411862393666e-11,
#   2.537526121588936e-11,
#   2.407306932704933e-11,
#   2.5329579386422112e-11,
#   2.4870815124615754e-11,
#   2.4241334456807853e-11,
#   2.4473421007870993e-11]}

# %%
def plot_TEP_PIB_continental(L1,L2,L3,L4):
    plt.figure()
    plt.plot(L_annee,L1)
    plt.plot(L_annee,L2)
    plt.plot(L_annee,L3)
    plt.plot(L_annee,L4)
    plt.legend([continent for continent in Region_possible])
    plt.xlabel("Année")
    plt.ylabel("TEP/PIB")
    plt.show()
    return

# %%
TP=TEP_PIB_4continents(89,pop,1235000,9845500,False,False,False,1536852,6548213,False,True,True,4561237,5462137,False,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,False,True,False,cfc,fbcfc,vsc,continents,xc,mc)
L1=TP['Europe']
L2=TP['Amérique du Nord']
L3=TP['Asie']
L4=TP['Afrique']

# %%
plot_TEP_PIB_continental(L1,L2,L3,L4)

# %% [markdown]
# ### 3) CO2/TEP

# %%
def CO2_TEP_mondial(P,a):
    TEP=[]
    CO2=valeur(2010+a+1)
    CO2bis=[]
    co2_tep=[]
    for i in range(0,a+1):
        TEP.append(energy(P,2010+i))
        CO2bis.append(CO2[2010+i])
        co2_tep.append((CO2bis[i])/(TEP[i]))
    return co2_tep

# %%
L_annee2=[i for i in range(2010,2051)]
def plot_CO2_TEP(L):
    plt.figure()
    plt.plot(L_annee2,L)
    plt.xlabel("Année")
    plt.ylabel("CO2/TEP")
    plt.show()
    return

# %%
L=CO2_TEP_mondial('Monde',40)

# %%
plot_CO2_TEP(L)

# %%
def NAp(year):
    X=Année_t
    Y=NA
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    return slope*year + intercept
    
def Asiep(year):
    X=Année_t
    Y=Asie
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    return slope*year + intercept

def EUp(year):
    X=Année_t
    Y=EU
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    return slope*year + intercept

def Afrip(year):
    X=Année_t
    Y=Afri
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    return slope*year + intercept

# %%
def dict_co2_4_continents(a):
    D={'Europe':[],'Afrique':[],'Asie':[],'Amérique du Nord':[]}
    for i in range(0,a+1):
        D['Europe'].append(EUp(2010+i))
        D['Afrique'].append(Afrip(2010+i))
        D['Asie'].append(Asiep(2010+i))
        D['Amérique du Nord'].append(NAp(2010+i))
    return D

# %%
dict_co2_4_continents(40)
# Out:
# {'Afrique': [2.1533320258159705,
#   2.18721827936875,
#   2.2211045329215295,
#   2.254990786474309,
#   2.2888770400270744,
#   2.322763293579854,
#   2.3566495471326334,
#   2.390535800685413,
#   2.4244220542381925,
#   2.458308307790972,
#   2.4921945613437515,
#   2.526080814896531,
#   2.5599670684492963,
#   2.593853322002076,
#   2.6277395755548554,
#   2.661625829107635,
#   2.6955120826604144,
#   2.729398336213194,
#   2.7632845897659735,
#   2.7971708433187388,
#   2.8310570968715183,
#   2.864943350424298,
#   2.8988296039770773,
#   2.932715857529857,
#   2.9666021110826364,
#   3.000488364635416,
#   3.0343746181881954,
#   3.0682608717409607,
#   3.1021471252937403,
#   3.13603337884652,
#   3.1699196323992993,
#   3.203805885952079,
#   3.2376921395048583,
#   3.271578393057638,
#   3.3054646466104174,
#   3.3393509001631827,
#   3.3732371537159622,
#   3.4071234072687417,
#   3.4410096608215213,
#   3.474895914374301,
#   3.5087821679270803],
#  'Amérique du Nord': [3.6541342261830536,
#   3.6849261806947524,
#   3.7157181352064512,
#   3.746510089718143,
#   3.7773020442298417,
#   3.8080939987415405,
#   3.8388859532532322,
#   3.869677907764931,
#   3.9004698622766227,
#   3.9312618167883215,
#   3.9620537713000203,
#   3.992845725811712,
#   4.023637680323411,
#   4.05442963483511,
#   4.085221589346801,
#   4.1160135438585,
#   4.146805498370192,
#   4.177597452881891,
#   4.2083894073935895,
#   4.239181361905281,
#   4.26997331641698,
#   4.300765270928672,
#   4.3315572254403705,
#   4.362349179952069,
#   4.393141134463761,
#   4.42393308897546,
#   4.454725043487159,
#   4.48551699799885,
#   4.516308952510549,
#   4.547100907022241,
#   4.57789286153394,
#   4.608684816045638,
#   4.63947677055733,
#   4.670268725069029,
#   4.701060679580728,
#   4.731852634092419,
#   4.762644588604118,
#   4.79343654311581,
#   4.824228497627509,
#   4.8550204521392075,
#   4.885812406650899],
#  'Asie': [6.975563801621831,
#   7.1061615869849675,
#   7.236759372348104,
#   7.36735715771124,
#   7.497954943074433,
#   7.628552728437569,
#   7.759150513800705,
#   7.889748299163841,
#   8.020346084526977,
#   8.150943869890114,
#   8.28154165525325,
#   8.412139440616443,
#   8.542737225979579,
#   8.673335011342715,
#   8.803932796705851,
#   8.934530582068987,
#   9.065128367432123,
#   9.19572615279526,
#   9.326323938158396,
#   9.456921723521589,
#   9.587519508884725,
#   9.718117294247861,
#   9.848715079610997,
#   9.979312864974133,
#   10.10991065033727,
#   10.240508435700406,
#   10.371106221063542,
#   10.501704006426735,
#   10.632301791789871,
#   10.762899577153007,
#   10.893497362516143,
#   11.02409514787928,
#   11.154692933242416,
#   11.285290718605552,
#   11.415888503968688,
#   11.546486289331881,
#   11.677084074695017,
#   11.807681860058153,
#   11.93827964542129,
#   12.068877430784426,
#   12.199475216147562],
#  'Europe': [1.995936129112735,
#   1.9440487945171157,
#   1.8921614599214962,
#   1.8402741253258768,
#   1.7883867907302573,
#   1.7364994561346379,
#   1.6846121215390184,
#   1.632724786943399,
#   1.5808374523477795,
#   1.52895011775216,
#   1.4770627831565406,
#   1.4251754485609212,
#   1.3732881139652875,
#   1.321400779369668,
#   1.2695134447740486,
#   1.2176261101784291,
#   1.1657387755828097,
#   1.1138514409871902,
#   1.0619641063915708,
#   1.0100767717959513,
#   0.9581894372003319,
#   0.9063021026047124,
#   0.854414768009093,
#   0.8025274334134735,
#   0.7506400988178541,
#   0.6987527642222346,
#   0.6468654296266152,
#   0.5949780950309957,
#   0.5430907604353763,
#   0.49120342583975685,
#   0.4393160912441232,
#   0.38742875664850374,
#   0.3355414220528843,
#   0.28365408745726484,
#   0.2317667528616454,
#   0.17987941826602594,
#   0.1279920836704065,
#   0.07610474907478704,
#   0.024217414479167587,
#   -0.027669920116451863,
#   -0.07955725471207131]}

# %%
def CO2_TEP_4continents(a, pop, n1, m1, probleme1, positif1, fixe1, n2, m2, probleme2, positif2, fixe2,n3, m3, probleme3, positif3, fixe3, n4, m4, probleme4, positif4, fixe4):
    D={'Europe':[],'Amérique du Nord':[],'Asie':[],'Afrique':[]}
    TEP=dict_energie_comsommé_tot(2010+a, pop, n1, m1, probleme1, positif1, fixe1, n2, m2, probleme2, positif2, fixe2,n3, m3, probleme3, positif3, fixe3, n4, m4, probleme4, positif4, fixe4)
    CO2=dict_co2_4_continents(a)
    for i in range(0,a+1):
        for k in TEP:
            D[k].append((CO2[k][i])/(TEP[k][i]))
    return D

# %%
CO2_TEP_4continents(40,pop,1235000,9845500,False,False,False,1536852,6548213,False,True,True,4561237,5462137,False,False,True,7531596,6547821,False,True,False)
# Out:
# {'Afrique': [0.002806059031842772,
#   0.002742035941521887,
#   0.002679145405830174,
#   0.0026176446606920294,
#   0.002557809128473833,
#   0.002499800956521194,
#   0.00244362765976003,
#   0.002370647987756023,
#   0.002318126159697838,
#   0.0022666465550908277,
#   0.0022161959829807938,
#   0.0021667608602258465,
#   0.0021183272711050444,
#   0.0020708810159793104,
#   0.0020244076593951155,
#   0.001978892576883325,
#   0.0019343209862799644,
#   0.0018906779922530986,
#   0.0018479486145764783,
#   0.0018061178182126225,
#   0.0017651705420710366,
#   0.0017250917223249234,
#   0.0016858663160402615,
#   0.0016474793209898682,
#   0.001609915794877051,
#   0.0015731608696972342,
#   0.0015371997708135796,
#   0.0015020178264759344,
#   0.0014676004836317491,
#   0.001433933316509121,
#   0.0014010020374869976,
#   0.0013687925063059117,
#   0.0013372907355513807,
#   0.0013064829005205755,
#   0.0012763553440610202,
#   0.0012468945816925233,
#   0.0012180873058347556,
#   0.0011899203901801535,
#   0.0011623808935936168,
#   0.001135456061882638,
#   0.001109133330733228],
#  'Amérique du Nord': [0.008095672920316913,
#   0.008023205126183416,
#   0.007954537922450173,
#   0.007888794119461815,
#   0.0078247719429814,
#   0.007761628185773059,
#   0.007699190201134227,
#   0.007680310358858809,
#   0.007620140675988018,
#   0.007560511665146553,
#   0.007501416348725352,
#   0.007442847890516072,
#   0.00738479967024747,
#   0.007327265137646112,
#   0.007270237946942321,
#   0.007213711834405977,
#   0.007157680729146326,
#   0.007102138652867995,
#   0.007047079772270778,
#   0.006992498340256064,
#   0.006938388764442647,
#   0.006884745549005578,
#   0.006831563309237079,
#   0.006778836751288176,
#   0.0067265607193512985,
#   0.006674730125083865,
#   0.006623339962890309,
#   0.0065723853709630875,
#   0.0065218615473616225,
#   0.006471763749586882,
#   0.006422087369316152,
#   0.00637282785234896,
#   0.0063239807421188714,
#   0.006275541633071295,
#   0.006227506198812662,
#   0.006179870231669677,
#   0.0061326295274758205,
#   0.006085779983398772,
#   0.006039317580497868,
#   0.005993238341365426,
#   0.0059475383560971],
#  'Asie': [0.005101685392990271,
#   0.005033350688588872,
#   0.004967011855826153,
#   0.004902814142853635,
#   0.0048409714095808245,
#   0.004781618055266363,
#   0.004724714950378164,
#   0.004643095886619118,
#   0.004594168692898946,
#   0.004546080984677167,
#   0.00449880105081091,
#   0.004452299232476966,
#   0.004406547754333274,
#   0.00436152056436128,
#   0.004317193196831212,
#   0.004273542638821262,
#   0.004230547223534497,
#   0.004188186518190304,
#   0.004146441234180737,
#   0.004105293140432788,
#   0.004064724984581652,
#   0.00402472042114865,
#   0.003985263947567553,
#   0.003946340844936483,
#   0.003907937123795,
#   0.0038700394729597764,
#   0.003832635214062829,
#   0.003795712261208949,
#   0.0037592590817343806,
#   0.003723264658715641,
#   0.003687718460502828,
#   0.0036526104098938412,
#   0.0036179308563188935,
#   0.0035836705475582233,
#   0.003549820610527054,
#   0.0035163725253196496,
#   0.003483318104875089,
#   0.0034506494778733126,
#   0.0034183590692714316,
#   0.003386439585118461,
#   0.0033548839949930505],
#  'Europe': [0.007539105467200552,
#   0.007280247645343919,
#   0.007027701172315125,
#   0.006780709359719744,
#   0.006538297113856078,
#   0.006299808176881636,
#   0.006065066727038076,
#   0.005811671112597465,
#   0.0054383454479517476,
#   0.005083396839193832,
#   0.004740596854082361,
#   0.004399286064623722,
#   0.0041199929839237336,
#   0.0038408892910362508,
#   0.003532370028032268,
#   0.0032760819916020215,
#   0.0030671531964001006,
#   0.0028502746459552206,
#   0.002616522679893757,
#   0.0024870752821691032,
#   0.0023024621470905397,
#   0.002133263947526146,
#   0.0019780367665565685,
#   0.001810133514968898,
#   0.0016704172262632206,
#   0.001502242957335764,
#   0.0013483394499513384,
#   0.0012170944617362594,
#   0.0010819714014416218,
#   0.000984740447933398,
#   0.0008500554050879837,
#   0.0007508652390008486,
#   0.0006122513060626894,
#   0.0005303895982290195,
#   0.0004287219800806954,
#   0.0003188329268139589,
#   0.00022164169812686381,
#   0.00012827752214195697,
#   4.117465354594214e-05,
#   -4.485542263158678e-05,
#   -0.0001293152515650612]}

# %%
def plot_CO2_TEP_continental(L1,L2,L3,L4):
    plt.figure()
    plt.plot(L_annee,L1)
    plt.plot(L_annee,L2)
    plt.plot(L_annee,L3)
    plt.plot(L_annee,L4)
    plt.legend([continent for continent in Region_possible])
    plt.xlabel("Année")
    plt.ylabel("CO2/TEP")
    plt.show()
    return

# %%
co2_tep=CO2_TEP_4continents(89,pop,1235000,9845500,False,False,False,1536852,6548213,False,True,True,4561237,5462137,False,False,True,7531596,6547821,False,True,False)
L1=co2_tep['Europe']
L2=co2_tep['Amérique du Nord']
L3=co2_tep['Asie']
L4=co2_tep['Afrique']

# %%
plot_CO2_TEP_continental(L1,L2,L3,L4)

# %% [markdown]
# # Modèle témoin

# %%
Pibpop=PIB_POP_bis(90,pop,1235000,9845500,False,False,False,1536852,6548213,False,True,True,4561237,5462137,False,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,False,True,False)

# %%
Pibpop[40]/Pibpop[0]
# Out:
# 1.210111411885307

# %%
L7[40]/L7[0]
# Out:
# 1.5726625565258123

# %%
Teppib=TEP_PIBbis('Monde',90)

# %%
Teppib[40]/Teppib[0]
# Out:
# 0.8527822886294578

# %%
Co2tep=CO2_TEP_mondial('Monde',40)

# %%
Co2tep[40]/Co2tep[0]
# Out:
# 0.9034817347279724

# %%
Co2tep[40]
# Out:
# 0.0012211323873699937

# %%
L7[40]
# Out:
# 10898119099

# %%
Teppib[40]
# Out:
# 1.8567906812493488e-10

# %%
Pibpop[40]
# Out:
# 10090.77404462446

# %%
Teppibbis=[0.5657*Teppib[i] for i in range(len(Teppib))]

# %%
Co2tepbis=[0.5657*Co2tep[i] for i in range(len(Co2tep))]

# %%
Lfinal1=[Co2tepbis[i]*Teppibbis[i]*Pibpop[i]*L7[i] for i in range(len(Co2tepbis))]

# %%
def plot_CO2_final1(L):
    plt.figure()
    plt.plot(L_annee2,L)
    plt.xlabel("Année")
    plt.ylabel("CO2")
    plt.show()
    return

# %%
plot_CO2_final1(Lfinal1)

# %%
Lfinal1[40]
# Out:
# 7.979470737853194

# %% [markdown]
# 1er scénario imaginé:
#
# Pop varie normalement (selon le solde défini).
#
# Pib/Pop varie normalement.
#
# Tep/Pib varie selon un facteur 0.5657.
#
# Co2/Tep varie également selon un facteur 0.5657.

# %%
Teppibbis2=[0.8*Teppib[i] for i in range(len(Teppib))]

# %%
Co2tepbis2=[0.4*Co2tep[i] for i in range(len(Co2tep))]

# %%
Lfinal2=[Co2tepbis2[i]*Teppibbis2[i]*Pibpop[i]*L7[i] for i in range(len(Co2tepbis2))]

# %%
plot_CO2_final1(Lfinal2)

# %% [markdown]
# Modèle 3:
# Ce modèle a pour objectif de réduire nos émissions de façon drastique.
# Objectif : avoir les émissions de co2 de 2100 égale au émissions de 1970 (avant la révolution insdustrielle)

# %%
def co2_tep_bis(P, annee_debut, annee_final, annee_chute, pourcentage, f1, f0):
    
    X_co2 = Année_t
    Y_co2 = [NA[i]+SA[i]+EU[i]+Afri[i]+Oce[i]+Asie[i] for i in range(0,len(NA))]    
    slope, intercept, r_value, p_value, std_err = stats.linregress(X_co2, Y_co2)
    
    annee = [i for i in range(annee_debut, annee_final)]
    
    co2 = slope*np.asarray(annee) + intercept       
    tep = energie_avec_chute(P,annee_debut, annee_final, annee_chute,pourcentage)
    
    co2_tep = []     
    for i in range(0, len(annee)):
        co2_tep.append((co2[i]*f1/tep[i]*f0))
                       
    return co2_tep

    plt.show()
    
def tep_pib_bis(P, annee_debut, annee_final, annee_chute, pourcentage, f2, f0):
       
    annee_pib = pib_data.iloc[0:len(pib_data),0]
    PIB = pib_data.iloc[0:len(pib_data),1] 
    X_pib=[i for i in annee_pib]
    Y_pib=[i for i in PIB]
    slope, intercept, r_value, p_value, std_err = stats.linregress(X_pib, Y_pib)

    annee = [i for i in range(annee_debut, annee_final)]
       
    pib = slope*np.asarray(annee) + intercept 
    tep = energie_avec_chute(P,annee_debut, annee_final, annee_chute,pourcentage)
    tep_pib = []
    
    for i in range(0, len(annee)):
        tep_pib.append(tep[i]*f0/(pib[i]*f2))
        
    return tep_pib   
        
def pib_pop_bis(annee_debut, annee_final, a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,
       fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6, f2, f3):

    X_pop = [i for i in range(2010, 2010+a)]
    Y_pop = L7(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,
           fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6)
    slope1, intercept1, r_value, p_value, std_err = stats.linregress(X_pop, Y_pop)
    
    annee = [i for i in range(annee_debut, annee_final)]
    
    pop = slope1*np.asarray(annee) + intercept1
    
    annee_pib = pib_data.iloc[0:len(pib_data),0]
    PIB = pib_data.iloc[0:len(pib_data),1] 
    X_pib=[i for i in annee_pib]
    Y_pib=[i for i in PIB]
    slope2, intercept2, r_value, p_value, std_err = stats.linregress(X_pib, Y_pib)

    pib = slope2*np.asarray(annee) + intercept2
    
    pib_pop=[]
    for i in range(0, len(annee)):
        pib_pop.append((pib[i]*f2)/(pop[i]*f3))
    return pib_pop

def popu_bis(annee_debut, annee_final, a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,
       fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6, f3):
    
    X_pop = [i for i in range(2010, 2010+a)]
    Y_pop = L7(a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,
           fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6)
    slope1, intercept1, r_value, p_value, std_err = stats.linregress(X_pop, Y_pop)
    
    annee = [i for i in range(annee_debut, annee_final)]
    
    return (slope1*np.asarray(annee) + intercept1)*f3

def kaya_modele3(P, annee_chute, pourcentage,f0, f1, f2, f3, annee_debut, annee_final, a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,
       fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6):

    annee = [i for i in range(annee_debut, annee_final)]
    
    co2_tep = co2_tep_bis(P, annee_debut, annee_final, annee_chute, pourcentage, f1, f0)
    tep_pib = tep_pib_bis(P, annee_debut, annee_final, annee_chute, pourcentage, f2, f0)
    pip_pop = pib_pop_bis(annee_debut, annee_final, a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,
                          fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6, f2,f3)
    popu = popu_bis(annee_debut, annee_final, a,pop,n1,m1,probleme1,positif1,fixe1,n2,m2,probleme2,positif2,fixe2,n3,m3,probleme3,positif3,fixe3,n4,m4,probleme4,positif4,
        fixe4,n5,m5,probleme5,positif5,fixe5,n6,m6,probleme6,positif6,fixe6,f3)
    
    Y_kaya =[]
    
    for i in range(0, len(annee)):
        Y_kaya.append(co2_tep[i] * tep_pib[i] * pip_pop[i] * popu[i])
    if len(Y_kaya)==1:
        print(Y_kaya)
        
    axes = plt.axes()
    axes.grid()
    plt.title(P)
    plt.xlabel('Année')
    plt.ylabel('Millard de Co2')
    plt.scatter(annee,Y_kaya)
    plt.show()

# %%
kaya_modele3('Monde', 2019, 20, 0.7, 0.7, 1.5, 0.9 , 2019, 2100, 90,pop,1235000,9845500,False,False,False,1536852,6548213,False,True,True,4561237,5462137,False,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,False,True,False)

# %% [markdown]
# pour valider ce modèle, il faut diminuer notre consommation d'énergie de 30%, nos émissions de co2 de 30%, que notre pib augmente de 50% et que notre population croit de 10% de moins pour chaque année jusqu'en 2100

# %%
kaya_modele3('Monde', 2019, 0, 1, 1, 1, 1, 1970,1971, 90,pop,1235000,9845500,False,False,False,1536852,6548213,False,True,True,4561237,5462137,False,False,True,7531596,6547821,False,True,False,3216549,1642538,False,False,False,3214564,6513245,False,True,False)
# Out:
# [10.269219782101118]

# %% [markdown]
# # Scénario 1

# %%
Pibpop[20]/Pibpop[8]
# Out:
# 1.0737541631890095

# %%
L7[20]/L7[8]
# Out:
# 1.1358091626023015

# %%
Teppib[20]/Teppib[8]*0.67
# Out:
# 0.6354261798657621

# %%
(Co2tep[20]/Co2tep[8])*0.67
# Out:
# 0.6479310364606962

# %% [markdown]
# Scénario 2:
#
# Tout reste pareil sauf CO2/TEP.
#
# Scénario 3:
#
# Tout reste pareil sauf TEP/PIB.
#
# Scénario 4:
#
# Population diminue et PIB aussi.
